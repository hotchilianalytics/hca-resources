# %%
# %%html
# <style>
#   table {margin-left: 0 !important;}
# </style>
# Out:
# <style>
#   table {margin-left: 0 !important;}
# </style>

# %% [markdown]
# <img src="http://drive.google.com/uc?export=view&id=1zJjN-vEjutF__7wpEq5Yibxv9BRZeC74"
#      alt="HCA Logo" height="150" width="150"
#      style="float: left; margin-right: 10px;">
#
# |Name  | Value |
# | :- |:-------------: |
# | **Notebook:**  | **HotChili Trader Tear Sheet** |
# | **Version:**  | 1.0.1c |
# | **Date:**  | 2020-08-06  |
# | **Copyright:**  | @2019-2020 |
# | **Company:**  | **HotChili Analytics, LLC** |
# | **Author   :**  | Alan Coppola|(ajjcoppola@hotchilianalytics.com) |
# | **Author   :**  | Jeff Coppola|(jeff@hotchilianalytics.com) |

# %%
import pandas as pd
import numpy as np
import matplotlib as mp
import matplotlib.pyplot as plt
import pyfolio as pf
# %matplotlib inline

# silence warnings
import warnings
warnings.filterwarnings('ignore')
### %pylab inline
###figsize(12, 12)
# Out:
# WARNING (theano.configdefaults): install mkl with `conda install mkl-service`: No module named 'mkl'

# %%
pd.set_option("max_colwidth", 400)
pd.set_option("display.max_rows", 100000)
pd.set_option("display.max_columns", 1000)
pd.set_option('precision', 2)
pd.options.display.float_format = '{:20,.2f}'.format

# %%
# Parameters for location of zipline-broker run
#hca/hca-resources/HCA_Fundamentals/fund_bt.pkl
#hca/hca-resources/HCA_Fundamentals/fund_bt.pkl
nb_dir = "/home/hca-dev/hca/hca-resources/HCA_Fundamentals/"
ans_pkl = "fund_bt.pkl"
ans_data_file = nb_dir + ans_pkl

# Read in backtest results for analysis
perf=pd.read_pickle(ans_data_file)

# %%
perf.columns
#dir(perf)
# Out:
# Index(['algo_volatility', 'algorithm_period_return', 'alpha',
#        'benchmark_period_return', 'benchmark_volatility', 'beta',
#        'capital_used', 'ending_cash', 'ending_exposure', 'ending_value',
#        'excess_return', 'gross_leverage', 'leverage', 'long_count',
#        'long_exposure', 'long_value', 'longs_count', 'max_drawdown',
#        'max_leverage', 'net_leverage', 'orders', 'period_close',
#        'period_label', 'period_open', 'pnl', 'port_wts', 'portfolio_value',
#        'positions', 'returns', 'sharpe', 'short_count', 'short_exposure',
#        'short_value', 'shorts_count', 'sortino', 'starting_cash',
#        'starting_exposure', 'starting_value', 'trading_days', 'transactions',
#        'treasury_period_return'],
#       dtype='object')

# %%
perf.shape
# Out:
# (510, 41)

# %%
import pandas as pd
returns, positions, transactions= pf.utils.extract_rets_pos_txn_from_zipline(perf)

# %%
#positions

# %%
#transactions

# %%
import sys

print("Tear Sheet File : {}".format(ans_data_file))
print("-----------------------------------")
print("Python version={}".format(sys.version))
print("Matplotlib version={}".format(mp.__version__))
print("Numpy version={}".format(np.version.version))
# Out:
# Tear Sheet File : /home/hca-dev/hca/hca-resources/HCA_Fundamentals/fund_bt.pkl
# -----------------------------------
# Python version=3.6.7 |Anaconda, Inc.| (default, Oct 23 2018, 19:16:44)
# [GCC 7.3.0]
# Matplotlib version=3.1.1
# Numpy version=1.14.1

# %%
#pf.plot_drawdown_periods(returns, top=5).set_xlabel('Date')

# %%
#returns.plot()

# %%
#transactions

# %%
#from datetime import datetime
#import pytz
#start = datetime(2017, 2, 11, 0, 0, 0, 0, pytz.utc)
#end = datetime(2019, 3, 14, 0, 0, 0, 0, pytz.utc)
#s=pd.Timestamp(start)

# %%
#pf.create_position_tear_sheet(returns=returns,positions=positions)
#pf.plot_perf_stats(returns= returns, factor_returns=returns)

# %%
sim_start=perf.index[0]
sim_end= perf.index[-1]
print("start={}  end={}".format(sim_start,sim_end))
# Out:
# start=2019-02-04 00:00:00+00:00  end=2021-02-10 00:00:00+00:00

# %%
#%%pixie_debugger

from zipline.data import benchmarks
# Set up benchmark Asset 
spy_bm_ret    = benchmarks.get_benchmark_returns(symbol='SPY', first_date=sim_start, last_date=sim_end)
spy_bm_ret    = spy_bm_ret[sim_start:sim_end]
spy_bm_ret[0] = 0.0 # Normalize benchmark returns to start at 0.0.
perf          = perf[sim_start:sim_end]

returns, positions, transactions = pf.utils.extract_rets_pos_txn_from_zipline(perf)
#pf.create_txn_tear_sheet(returns, positions=positions, transactions=transactions)
#pf.create_round_trip_tear_sheet(returns, positions=positions, transactions=transactions)
pf.create_full_tear_sheet(returns, positions=positions, transactions=transactions, bootstrap=None,benchmark_rets=spy_bm_ret, round_trips=True)
#pf.create_simple_tear_sheet(returns=returns,positions=positions,transactions=transactions,benchmark_rets=spy_bm_ret)
# Out:
# Entire data start date: 2019-02-05
# Entire data end date: 2021-02-10
# Backtest months: 24
#                     Backtest
# Annual return          13.2%
# Cumulative returns     28.4%
# Annual volatility      31.7%
# Sharpe ratio            0.55
# Calmar ratio            0.34
# Stability               0.20
# Max drawdown          -38.5%
# Omega ratio             1.11
# Sortino ratio           0.74
# Skew                   -1.18
# Kurtosis                7.79
# Tail ratio              1.02
# Daily value at risk    -3.9%
# Gross leverage          1.00
# Daily turnover          8.0%
# Alpha                  -0.05
# Beta                    1.05
# Worst drawdown periods Net drawdown in %  Peak date Valley date Recovery date  \
# 0                                  38.49 2020-02-19  2020-03-23    2020-06-04
# 1                                  20.88 2020-06-08  2020-06-26    2020-12-04
# 2                                  11.18 2019-07-15  2019-10-02    2019-12-24
# 3                                   9.62 2019-05-03  2019-05-31    2019-06-28
# 4                                   6.81 2021-01-07  2021-01-29           NaT
#
# Worst drawdown periods Duration
# 0                            77
# 1                           130
# 2                           117
# 3                            41
# 4                           NaN
# Stress Events  mean     min   max
# New Normal    0.07% -11.25% 7.98%
# Top 10 long positions of all time     max
# IEF                               100.16%
# INMD                               22.12%
# AG                                 21.93%
# PINS                               21.80%
# CRWD                               21.48%
# CODX                               20.04%
# CWH                                16.58%
# ELY                                14.93%
# AMD                                14.05%
# OKE                                13.96%
# Empty DataFrame
# Columns: [max]
# Index: []
# Top 10 positions of all time     max
# IEF                          100.16%
# INMD                          22.12%
# AG                            21.93%
# PINS                          21.80%
# CRWD                          21.48%
# CODX                          20.04%
# CWH                           16.58%
# ELY                           14.93%
# AMD                           14.05%
# OKE                           13.96%
# All positions ever held     max
# IEF                     100.16%
# INMD                     22.12%
# AG                       21.93%
# PINS                     21.80%
# CRWD                     21.48%
# CODX                     20.04%
# CWH                      16.58%
# ELY                      14.93%
# AMD                      14.05%
# OKE                      13.96%
# IWR                      13.87%
# GUSH                     13.52%
# LNG                      13.43%
# CRON                     13.29%
# ALL                      12.78%
# KKR                      12.72%
# A                        12.69%
# CAT                      12.36%
# ADI                      12.13%
# ICE                      11.48%
# PEAK                     11.40%
# FSCT                     11.29%
# FISV                     11.26%
# CVS                      11.06%
# FRC                      10.08%
# AAXJ                     10.06%
# PFF                       9.98%
# IRM                       9.97%
# AMCR                      9.91%
# BRO                       9.72%
# PCY                       9.49%
# NFLX                      9.36%
# BCE                       8.96%
# PLAY                      8.96%
# GES                       8.89%
# BRX                       8.56%
# CSTM                      8.47%
# LACQ                      8.39%
# AXSM                      8.38%
# ACI                       8.07%
# CDAY                      8.04%
# AA                        8.00%
# BOIL                      7.96%
# ATO                       7.89%
# BVN                       7.88%
# GFI                       7.87%
# HIG                       7.82%
# LBTYK                     7.80%
# MAT                       7.75%
# NRZ                       7.75%
# ALK                       7.72%
# AMKR                      7.71%
# AMAG                      7.71%
# PHG                       7.65%
# FWONK                     7.60%
# CMI                       7.58%
# NVS                       7.57%
# HOL                       7.56%
# CPRI                      7.47%
# NTEC                      7.41%
# GNOG                      7.39%
# EQC                       7.38%
# NXPI                      7.37%
# EQX                       7.34%
# ALKS                      7.32%
# BWEN                      7.32%
# MTG                       7.31%
# PH                        7.31%
# GBT                       7.29%
# GH                        7.26%
# ASAN                      7.26%
# NEA                       7.24%
# JNCE                      7.23%
# GBDC                      7.16%
# MTCN                      7.15%
# NETE                      7.15%
# LKQ                       7.05%
# HFXI                      7.04%
# MDB                       7.03%
# KMI                       7.01%
# CDLX                      7.00%
# EBND                      7.00%
# CURO                      6.99%
# CC                        6.97%
# NAIL                      6.86%
# CMA                       6.86%
# GWPH                      6.86%
# ATI                       6.86%
# AINV                      6.85%
# JRVR                      6.85%
# CLCT                      6.84%
# ATHA                      6.82%
# FPE                       6.81%
# HQY                       6.80%
# HPK                       6.80%
# AME                       6.79%
# EWS                       6.77%
# DBEU                      6.76%
# IMVT                      6.75%
# DRI                       6.75%
# EWC                       6.75%
# LIVN                      6.74%
# FMS                       6.73%
# H                         6.72%
# ILPT                      6.70%
# MYOV                      6.69%
# CDNA                      6.69%
# LMBS                      6.66%
# CBMG                      6.63%
# LKNCY                     6.62%
# DENN                      6.62%
# GOL                       6.61%
# EIM                       6.60%
# HTGC                      6.58%
# GIS                       6.56%
# FLDM                      6.54%
# ALGM                      6.53%
# CTRE                      6.52%
# ACEV                      6.43%
# FUN                       6.38%
# Summary stats                All trades  Long trades
# Total number of round_trips     1004.00      1004.00
# Percent profitable                 0.62         0.62
# Winning round_trips              622.00       622.00
# Losing round_trips               382.00       382.00
# Even round_trips                   0.00         0.00
# PnL stats                 All trades  Long trades
# Total profit               $24853.88    $24853.88
# Gross profit              $148366.47   $148366.47
# Gross loss               $-123512.59  $-123512.59
# Profit factor                  $1.20        $1.20
# Avg. trade net profit         $24.75       $24.75
# Avg. winning trade           $238.53      $238.53
# Avg. losing trade           $-323.33     $-323.33
# Ratio Avg. Win:Avg. Loss       $0.74        $0.74
# Largest winning trade       $3379.02     $3379.02
# Largest losing trade       $-4572.30    $-4572.30
# Duration stats                 All trades             Long trades
# Avg duration      23 days 22:10:45.433266 23 days 22:10:45.433266
# Median duration          14 days 00:00:00        14 days 00:00:00
# Longest duration        126 days 01:00:00       126 days 01:00:00
# Shortest duration         3 days 00:00:00         3 days 00:00:00
# Return stats                    All trades  Long trades
# Avg returns all round_trips          0.01%        0.01%
# Avg returns winning                  0.22%        0.22%
# Avg returns losing                  -0.33%       -0.33%
# Median returns all round_trips       0.01%        0.01%
# Median returns winning               0.07%        0.07%
# Median returns losing               -0.15%       -0.15%
# Largest winning trade                3.19%        3.19%
# Largest losing trade                -5.96%       -5.96%
# Symbol stats                        A     AA   AAXJ   ACEV    ACI    ADI  \
# Avg returns all round_trips     0.03%  0.11% -0.01% -0.29%  0.02%  0.02%
# Avg returns winning             0.11%  0.23%  0.09%   nan%  0.15%  0.17%
# Avg returns losing             -0.16% -0.49% -0.14% -0.29% -0.10% -0.18%
# Median returns all round_trips  0.02%  0.04%  0.02% -0.29% -0.00%  0.00%
# Median returns winning          0.06%  0.04%  0.06%   nan%  0.02%  0.02%
# Median returns losing          -0.05% -0.49% -0.11% -0.29% -0.01% -0.08%
# Largest winning trade           0.52%  0.89%  0.38% -0.29%  0.57%  1.04%
# Largest losing trade           -0.69% -0.65% -0.28% -0.29% -0.24% -0.78%
#
# Symbol stats                       AG  AINV  ALGM    ALK   ALKS    ALL   AMAG  \
# Avg returns all round_trips    -0.02% 0.01% 0.05%  0.01% -0.13%  0.00% -0.15%
# Avg returns winning             0.41% 0.01% 0.05%  0.20%  0.14%  0.16%  0.09%
# Avg returns losing             -0.50%  nan%  nan% -0.35% -0.81% -0.11% -0.40%
# Median returns all round_trips  0.00% 0.01% 0.05%  0.01%  0.00% -0.01%  0.02%
# Median returns winning          0.07% 0.01% 0.05%  0.04%  0.10%  0.03%  0.09%
# Median returns losing          -0.46%  nan%  nan% -0.41% -0.81% -0.05% -0.40%
# Largest winning trade           1.73% 0.01% 0.05%  1.09%  0.40%  0.74%  0.14%
# Largest losing trade           -1.42% 0.01% 0.05% -1.01% -1.24% -0.51% -0.79%
#
# Symbol stats                     AMCR    AMD    AME   AMKR   ASAN  ATHA  \
# Avg returns all round_trips    -0.11%  0.12%  0.04% -0.03%  0.04% 1.24%
# Avg returns winning             0.13%  0.26%  0.23%  0.81%  0.30% 1.24%
# Avg returns losing             -0.23% -0.21% -0.16% -0.20% -0.34%  nan%
# Median returns all round_trips -0.00%  0.07%  0.01% -0.13%  0.00% 1.24%
# Median returns winning          0.01%  0.14%  0.23%  0.81%  0.01% 1.24%
# Median returns losing          -0.17% -0.11% -0.16% -0.17% -0.34%  nan%
# Largest winning trade           0.65%  1.32%  0.29%  0.81%  0.88% 1.24%
# Largest losing trade           -0.83% -0.86% -0.17% -0.45% -0.56% 1.24%
#
# Symbol stats                      ATI   ATO   AXSM    BCE   BOIL    BRO  \
# Avg returns all round_trips    -0.23% 0.17%  0.22%  0.05%  0.26%  0.04%
# Avg returns winning              nan% 0.17%  0.57%  0.11%  0.43%  0.09%
# Avg returns losing             -0.23%  nan% -0.47% -0.09% -0.42% -0.14%
# Median returns all round_trips -0.27% 0.19%  0.16%  0.03%  0.07%  0.04%
# Median returns winning           nan% 0.19%  0.54%  0.06%  0.14%  0.06%
# Median returns losing          -0.27%  nan% -0.47% -0.09% -0.42% -0.14%
# Largest winning trade          -0.07% 0.25%  1.12%  0.31%  1.42%  0.26%
# Largest losing trade           -0.36% 0.08% -0.55% -0.16% -0.42% -0.25%
#
# Symbol stats                      BRX    BVN   BWEN    CAT  CBMG     CC  \
# Avg returns all round_trips    -0.05%  0.07% -0.12% -0.01% 0.08% -0.22%
# Avg returns winning             0.10%  0.47%   nan%  0.13% 0.08%   nan%
# Avg returns losing             -0.26% -0.34% -0.12% -0.39%  nan% -0.22%
# Median returns all round_trips  0.00% -0.02% -0.12%  0.01% 0.08% -0.22%
# Median returns winning          0.03%  0.58%   nan%  0.03% 0.08%   nan%
# Median returns losing          -0.16% -0.34% -0.12% -0.37%  nan% -0.22%
# Largest winning trade           0.62%  0.74% -0.12%  1.16% 0.08% -0.22%
# Largest losing trade           -0.98% -0.61% -0.12% -1.57% 0.08% -0.22%
#
# Symbol stats                     CDAY   CDLX   CDNA   CLCT    CMA    CMI  \
# Avg returns all round_trips    -0.23% -0.00% -0.19% -0.03% -0.08%  0.11%
# Avg returns winning             0.17%  0.13%   nan%   nan%  0.17%  0.16%
# Avg returns losing             -0.63% -0.25% -0.19% -0.03% -0.20% -0.01%
# Median returns all round_trips -0.16%  0.12% -0.19% -0.03% -0.14%  0.14%
# Median returns winning          0.17%  0.13%   nan%   nan%  0.17%  0.16%
# Median returns losing          -0.63% -0.25% -0.19% -0.03% -0.20% -0.01%
# Largest winning trade           0.22%  0.13% -0.19% -0.03%  0.17%  0.19%
# Largest losing trade           -0.84% -0.25% -0.19% -0.03% -0.26% -0.01%
#
# Symbol stats                     CODX   CPRI   CRON   CRWD   CSTM   CTRE  \
# Avg returns all round_trips     0.49% -0.23% -0.01%  0.02% -0.70% -0.04%
# Avg returns winning             0.66%  0.07%  0.45%  0.51%  0.16%   nan%
# Avg returns losing             -0.19% -0.43% -0.40% -0.68% -1.07% -0.04%
# Median returns all round_trips  0.48% -0.10% -0.01%  0.03% -0.10% -0.04%
# Median returns winning          0.52%  0.07%  0.04%  0.20%  0.04%   nan%
# Median returns losing          -0.19% -0.18% -0.53% -0.43% -0.32% -0.04%
# Largest winning trade           1.38%  0.14%  2.53%  2.19%  0.41% -0.04%
# Largest losing trade           -0.19% -1.00% -0.91% -2.22% -5.92% -0.04%
#
# Symbol stats                     CURO   CVS    CWH  DBEU  DENN    DRI   EBND  \
# Avg returns all round_trips    -0.42% 0.12%  0.35% 0.09% 0.13% -0.14% -0.17%
# Avg returns winning              nan% 0.12%  0.96% 0.09% 0.13%   nan%   nan%
# Avg returns losing             -0.42%  nan% -0.40%  nan%  nan% -0.14% -0.17%
# Median returns all round_trips -0.42% 0.07%  0.20% 0.09% 0.13% -0.14% -0.17%
# Median returns winning           nan% 0.07%  0.56% 0.09% 0.13%   nan%   nan%
# Median returns losing          -0.42%  nan% -0.06%  nan%  nan% -0.14% -0.17%
# Largest winning trade          -0.42% 0.51%  2.86% 0.17% 0.13% -0.14% -0.17%
# Largest losing trade           -0.42% 0.00% -1.15% 0.01% 0.13% -0.14% -0.17%
#
# Symbol stats                     EIM   ELY    EQC    EQX    EWC    EWS   FISV  \
# Avg returns all round_trips    0.05% 2.35%  0.14%  0.02%  0.09% -0.11%  0.06%
# Avg returns winning            0.05% 2.35%  0.21%  0.20%  0.25%   nan%  0.10%
# Avg returns losing              nan%  nan% -0.01% -0.16% -0.06% -0.11% -0.12%
# Median returns all round_trips 0.05% 2.35%  0.04% -0.01%  0.09% -0.11%  0.01%
# Median returns winning         0.05% 2.35%  0.21%  0.20%  0.25%   nan%  0.01%
# Median returns losing           nan%  nan% -0.01% -0.16% -0.06% -0.11% -0.03%
# Largest winning trade          0.05% 2.35%  0.38%  0.28%  0.32% -0.04%  0.69%
# Largest losing trade           0.05% 2.35% -0.01% -0.17% -0.12% -0.18% -0.40%
#
# Symbol stats                     FLDM   FMS    FPE    FRC   FSCT    FUN  \
# Avg returns all round_trips    -1.83% 0.18%  0.03%  0.11% -0.34% -0.09%
# Avg returns winning              nan% 0.18%  0.06%  0.41%  0.54%   nan%
# Avg returns losing             -1.83%  nan% -0.00% -0.18% -0.93% -0.09%
# Median returns all round_trips -1.83% 0.18%  0.03%  0.04% -0.00% -0.09%
# Median returns winning           nan% 0.18%  0.06%  0.21%  0.54%   nan%
# Median returns losing          -1.83%  nan% -0.00% -0.22% -0.01% -0.09%
# Largest winning trade          -1.83% 0.18%  0.06%  0.83%  0.97% -0.09%
# Largest losing trade           -1.83% 0.18% -0.01% -0.25% -2.78% -0.09%
#
# Symbol stats                    FWONK   GBDC   GBT    GES    GFI     GH  \
# Avg returns all round_trips    -0.14% -0.02% 0.66%  0.11%  0.13% -0.38%
# Avg returns winning             0.22%   nan% 0.66%  0.29%  0.24%  0.01%
# Avg returns losing             -0.86% -0.02%  nan% -0.44% -0.64% -0.77%
# Median returns all round_trips  0.03% -0.02% 0.66%  0.08%  0.05% -0.12%
# Median returns winning          0.22%   nan% 0.66%  0.15%  0.07%  0.01%
# Median returns losing          -0.86% -0.02%  nan% -0.22% -0.64% -0.77%
# Largest winning trade           0.42% -0.01% 0.66%  1.18%  0.85%  0.01%
# Largest losing trade           -0.86% -0.02% 0.66% -1.13% -0.64% -1.28%
#
# Symbol stats                      GIS   GNOG   GOL   GUSH  GWPH     H  HFXI  \
# Avg returns all round_trips    -0.10% -1.52% 0.16%  0.56% 0.01% 0.08% 0.09%
# Avg returns winning              nan%   nan% 0.16%  0.74% 0.01% 0.08% 0.09%
# Avg returns losing             -0.10% -1.52%  nan% -1.19%  nan%  nan%  nan%
# Median returns all round_trips -0.10% -1.52% 0.16%  0.48% 0.01% 0.08% 0.09%
# Median returns winning           nan%   nan% 0.16%  0.49% 0.01% 0.08% 0.09%
# Median returns losing          -0.10% -1.52%  nan% -1.19%  nan%  nan%  nan%
# Largest winning trade          -0.10% -1.52% 0.16%  2.37% 0.01% 0.09% 0.14%
# Largest losing trade           -0.10% -1.52% 0.16% -1.19% 0.01% 0.06% 0.05%
#
# Symbol stats                      HIG    HOL    HPK   HQY  HTGC    ICE    IEF  \
# Avg returns all round_trips    -0.12% -0.23% -0.02% 0.09% 0.23%  0.02% -0.26%
# Avg returns winning             0.10%   nan%   nan% 0.09% 0.23%  0.12%   nan%
# Avg returns losing             -0.55% -0.23% -0.02%  nan%  nan% -0.15% -0.26%
# Median returns all round_trips  0.01% -0.23% -0.02% 0.09% 0.23%  0.01% -0.26%
# Median returns winning          0.07%   nan%   nan% 0.09% 0.23%  0.06%   nan%
# Median returns losing          -0.11% -0.23% -0.02%  nan%  nan% -0.17% -0.26%
# Largest winning trade           0.38% -0.23% -0.02% 0.09% 0.23%  0.43% -0.26%
# Largest losing trade           -1.95% -0.23% -0.02% 0.09% 0.23% -0.33% -0.26%
#
# Symbol stats                     ILPT  IMVT   INMD    IRM    IWR   JNCE  \
# Avg returns all round_trips    -0.44% 0.27%  0.10% -0.21%  0.08% -0.71%
# Avg returns winning              nan% 0.27%  0.63%  0.03%  0.21%   nan%
# Avg returns losing             -0.44%  nan% -0.78% -0.42% -0.80% -0.71%
# Median returns all round_trips -0.44% 0.27%  0.12% -0.00%  0.06% -0.71%
# Median returns winning           nan% 0.27%  0.17%  0.01%  0.12%   nan%
# Median returns losing          -0.44%  nan% -0.50% -0.16% -0.03% -0.71%
# Largest winning trade          -0.44% 0.27%  1.44%  0.09%  0.85% -0.71%
# Largest losing trade           -0.44% 0.27% -1.36% -2.16% -2.36% -0.71%
#
# Symbol stats                     JRVR    KKR    KMI   LACQ  LBTYK   LIVN  \
# Avg returns all round_trips    -0.23%  0.06%  0.05% -0.02% -0.07% -0.25%
# Avg returns winning              nan%  0.13%  0.22%   nan%  0.39%   nan%
# Avg returns losing             -0.23% -0.28% -0.22% -0.02% -0.23% -0.25%
# Median returns all round_trips -0.23%  0.03%  0.03% -0.02% -0.00% -0.25%
# Median returns winning           nan%  0.05%  0.27%   nan%  0.39%   nan%
# Median returns losing          -0.23% -0.04% -0.22% -0.02% -0.00% -0.25%
# Largest winning trade          -0.23%  1.35%  0.38% -0.02%  0.39% -0.25%
# Largest losing trade           -0.23% -1.38% -0.23% -0.02% -0.68% -0.25%
#
# Symbol stats                    LKNCY    LKQ  LMBS    LNG   MAT    MDB  MTCN  \
# Avg returns all round_trips    -0.62%  0.02% 0.03%  0.13% 0.23% -0.03% 0.24%
# Avg returns winning             0.39%  0.26% 0.03%  0.26% 0.23%  0.07% 0.24%
# Avg returns losing             -1.64% -0.38%  nan% -0.09%  nan% -0.22%  nan%
# Median returns all round_trips -0.62%  0.00% 0.03%  0.01% 0.02%  0.03% 0.24%
# Median returns winning          0.39%  0.02% 0.03%  0.12% 0.02%  0.07% 0.24%
# Median returns losing          -1.64% -0.13%  nan% -0.06%  nan% -0.22%  nan%
# Largest winning trade           0.39%  0.90% 0.03%  0.91% 1.29%  0.11% 0.24%
# Largest losing trade           -1.64% -1.01% 0.03% -0.42% 0.00% -0.22% 0.24%
#
# Symbol stats                     MTG   MYOV   NAIL    NEA   NETE   NFLX  \
# Avg returns all round_trips    0.07% -0.71% -0.99% -0.19% -0.57%  0.17%
# Avg returns winning            0.07%  0.16%   nan%   nan%   nan%  0.36%
# Avg returns losing              nan% -1.14% -0.99% -0.19% -0.57% -0.08%
# Median returns all round_trips 0.01% -0.51% -0.99% -0.19% -0.72%  0.00%
# Median returns winning         0.01%  0.16%   nan%   nan%   nan%  0.26%
# Median returns losing           nan% -1.14% -0.99% -0.19% -0.72% -0.09%
# Largest winning trade          0.44%  0.16% -0.99% -0.01% -0.05%  0.90%
# Largest losing trade           0.00% -1.77% -0.99% -0.37% -0.95% -0.12%
#
# Symbol stats                      NRZ   NTEC    NVS   NXPI    OKE    PCY  \
# Avg returns all round_trips    -0.13% -0.41% -0.03% -0.32% -0.06% -0.05%
# Avg returns winning              nan%   nan%  0.12%  0.15%  0.28%  0.08%
# Avg returns losing             -0.13% -0.41% -0.11% -0.86% -0.61% -0.16%
# Median returns all round_trips -0.12% -0.41% -0.01%  0.00%  0.00% -0.04%
# Median returns winning           nan%   nan%  0.11%  0.03%  0.09%  0.07%
# Median returns losing          -0.12% -0.41% -0.07% -0.66% -0.09% -0.07%
# Largest winning trade          -0.00% -0.41%  0.24%  0.56%  1.76%  0.14%
# Largest losing trade           -0.27% -0.41% -0.34% -2.91% -5.96% -0.51%
#
# Symbol stats                     PEAK    PFF     PH    PHG   PINS   PLAY
# Avg returns all round_trips     0.02%  0.02% -0.46%  0.24%  0.12%  0.19%
# Avg returns winning             0.07%  0.04%  0.16%  0.52%  0.41%  0.38%
# Avg returns losing             -0.12% -0.02% -0.87% -0.04% -0.43% -0.47%
# Median returns all round_trips  0.01%  0.00% -0.17%  0.00%  0.04%  0.26%
# Median returns winning          0.02%  0.01%  0.16%  0.52%  0.16%  0.31%
# Median returns losing          -0.10% -0.00% -0.31% -0.04% -0.28% -0.47%
# Largest winning trade           0.57%  0.11%  0.19%  1.01%  3.19%  0.83%
# Largest losing trade           -0.36% -0.06% -2.12% -0.06% -1.70% -0.58%
# Profitability (PnL / PnL total) per name
# symbol
# GUSH                                      28.53%
# AMD                                       22.91%
# LNG                                       17.18%
# PINS                                      15.98%
# KKR                                       15.08%
# CWH                                       13.95%
# GES                                       10.45%
# CODX                                       9.63%
# IWR                                        9.61%
# ELY                                        8.67%
# PLAY                                       7.60%
# FISV                                       6.52%
# BOIL                                       6.48%
# AA                                         5.88%
# MAT                                        5.72%
# AXSM                                       5.63%
# ATHA                                       5.39%
# ADI                                        5.26%
# GFI                                        4.89%
# CVS                                        4.63%
# NFLX                                       4.51%
# FRC                                        4.11%
# INMD                                       3.55%
# A                                          3.46%
# GBT                                        3.35%
# PHG                                        3.13%
# PEAK                                       2.96%
# MTG                                        2.79%
# CRON                                       2.44%
# BVN                                        2.40%
# ICE                                        2.34%
# ALK                                        2.15%
# ATO                                        2.11%
# BRO                                        2.04%
# LKQ                                        1.75%
# EWC                                        1.71%
# BCE                                        1.50%
# CMI                                        1.42%
# ALL                                        1.42%
# KMI                                        1.41%
# EQC                                        1.38%
# IMVT                                       1.18%
# ASAN                                       1.14%
# PFF                                        1.09%
# HTGC                                       1.06%
# MTCN                                       0.99%
# CAT                                        0.94%
# FMS                                        0.78%
# HFXI                                       0.73%
# DBEU                                       0.73%
# H                                          0.65%
# CRWD                                       0.64%
# GOL                                        0.63%
# DENN                                       0.52%
# AG                                         0.51%
# FPE                                        0.49%
# HQY                                        0.48%
# EQX                                        0.43%
# ACI                                        0.41%
# CBMG                                       0.33%
# AME                                        0.28%
# ALGM                                       0.27%
# EIM                                        0.21%
# LMBS                                       0.13%
# AINV                                       0.06%
# GWPH                                       0.05%
# CDLX                                      -0.01%
# LACQ                                      -0.07%
# HPK                                       -0.08%
# GBDC                                      -0.15%
# CLCT                                      -0.16%
# CTRE                                      -0.19%
# MDB                                       -0.36%
# FUN                                       -0.36%
# GIS                                       -0.37%
# AAXJ                                      -0.55%
# DRI                                       -0.57%
# BWEN                                      -0.57%
# OKE                                       -0.59%
# EBND                                      -0.68%
# CDNA                                      -0.85%
# EWS                                       -0.88%
# CC                                        -0.89%
# JRVR                                      -0.90%
# LIVN                                      -0.98%
# CMA                                       -1.00%
# IEF                                       -1.06%
# AMKR                                      -1.12%
# LBTYK                                     -1.12%
# HOL                                       -1.14%
# NEA                                       -1.18%
# NVS                                       -1.34%
# ACEV                                      -1.50%
# NRZ                                       -1.60%
# FWONK                                     -1.74%
# NTEC                                      -1.76%
# PCY                                       -1.78%
# ILPT                                      -1.82%
# CURO                                      -2.10%
# ALKS                                      -2.40%
# AMAG                                      -2.48%
# ATI                                       -2.89%
# CDAY                                      -2.97%
# JNCE                                      -3.53%
# HIG                                       -3.55%
# CPRI                                      -4.27%
# BRX                                       -4.67%
# NAIL                                      -4.91%
# GH                                        -6.16%
# FSCT                                      -6.24%
# LKNCY                                     -6.31%
# GNOG                                      -6.46%
# PH                                        -6.91%
# FLDM                                      -8.04%
# NETE                                      -8.09%
# IRM                                      -10.05%
# MYOV                                     -10.17%
# AMCR                                     -11.79%
# NXPI                                     -12.69%
# CSTM                                     -22.61%
