# %%
# %%html
# <style>
#     table {margin-left: 0 } !important;}
# </style>
# <style type="text/css">
#     table.dataframe td, table.dataframe th {border: 1px solid lightgray;}
# </style>
# Out:
# <style>
#     table {margin-left: 0 } !important;}
# </style>
# <style type="text/css">
#     table.dataframe td, table.dataframe th {border: 1px solid lightgray;}
# </style>

# %% [markdown]
# <img src="http://drive.google.com/uc?export=view&id=1zJjN-vEjutF__7wpEq5Yibxv9BRZeC74"
#      alt="HCA Logo" height="150" width="150"
#      style="float: left; margin-right: 10px;">
#
# |Name  | Value |
# | :- |:-------------: |
# | Notebook:  | HotChili Trader Tear Sheet |
# | Version:  | 2.0.0 |
# | Date:  | 2020-04-16  |
# | Copyright:  | @2019-2021 |
# | Company:  | HotChili Analytics, LLC |
# | Authors   :  | Alan & Jeff Coppola |

# %%
import pandas as pd
import numpy as np
import matplotlib as mp
import matplotlib.pyplot as plt
import pyfolio as pf
# %matplotlib inline

# silence warnings
import warnings
warnings.filterwarnings('ignore')
### %pylab inline
###figsize(12, 12)
# Out:
# WARNING (theano.configdefaults): install mkl with `conda install mkl-service`: No module named 'mkl'
# /home/hca-r2-001/miniconda3/envs/hca/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %%
pd.set_option("max_colwidth", 400)
pd.set_option("display.max_rows", 100000)
pd.set_option("display.max_columns", 1000)
pd.set_option('precision', 2)
pd.options.display.float_format = '{:20,.2f}'.format

# %%
# Parameters for location of zipline-broker run
#hca/hca-resources/HCA_Fundamentals/fund_bt.pkl
#hca/hca-resources/HCA_Fundamentals/fund_bt.pkl
nb_dir = "/home/hca-ws2004/hca/hca-resources/HCA_Fundamentals/"
ans_pkl = "HCA_Fundamentals_Live.pkl"
ans_data_file = nb_dir + ans_pkl

# Read in backtest results for analysis
perf=pd.read_pickle(ans_data_file)

# %%
perf.columns
#dir(perf)
# Out:
# Index(['algo_volatility', 'algorithm_period_return', 'alpha',
#        'benchmark_period_return', 'benchmark_volatility', 'beta',
#        'capital_used', 'ending_cash', 'ending_exposure', 'ending_value',
#        'excess_return', 'gross_leverage', 'leverage', 'long_count',
#        'long_exposure', 'long_value', 'longs_count', 'max_drawdown',
#        'max_leverage', 'net_leverage', 'orders', 'period_close',
#        'period_label', 'period_open', 'pnl', 'port_wts', 'portfolio_value',
#        'positions', 'returns', 'sharpe', 'short_count', 'short_exposure',
#        'short_value', 'shorts_count', 'sortino', 'starting_cash',
#        'starting_exposure', 'starting_value', 'trading_days', 'transactions',
#        'treasury_period_return'],
#       dtype='object')

# %%
perf.shape
# Out:
# (539, 41)

# %%
import pandas as pd
returns, positions, transactions= pf.utils.extract_rets_pos_txn_from_zipline(perf)

# %%
#positions

# %%
#transactions

# %%
import sys

print("Tear Sheet File : {}".format(ans_data_file))
print("-----------------------------------")
print("Python version={}".format(sys.version))
print("Matplotlib version={}".format(mp.__version__))
print("Numpy version={}".format(np.version.version))
# Out:
# Tear Sheet File : /home/hca-ws2004/hca/hca-resources/HCA_Fundamentals/HCA_Fundamentals_Live.pkl
# -----------------------------------
# Python version=3.6.7 |Anaconda, Inc.| (default, Oct 23 2018, 19:16:44)
# [GCC 7.3.0]
# Matplotlib version=3.1.1
# Numpy version=1.14.0

# %%
#pf.plot_drawdown_periods(returns, top=5).set_xlabel('Date')

# %%
#returns.plot()

# %%
#transactions

# %%
#from datetime import datetime
#import pytz
#start = datetime(2017, 2, 11, 0, 0, 0, 0, pytz.utc)
#end = datetime(2019, 3, 14, 0, 0, 0, 0, pytz.utc)
#s=pd.Timestamp(start)

# %%
#pf.create_position_tear_sheet(returns=returns,positions=positions)
#pf.plot_perf_stats(returns= returns, factor_returns=returns)

# %%
sim_start=perf.index[0]
sim_end= perf.index[-1]
print("start={}  end={}".format(sim_start,sim_end))
# Out:
# start=2019-04-01 00:00:00+00:00  end=2021-05-19 00:00:00+00:00

# %%
#%%pixie_debugger

from zipline.data import benchmarks
# Set up benchmark Asset 
spy_bm_ret    = benchmarks.get_benchmark_returns(symbol='SPY', first_date=sim_start, last_date=sim_end)
spy_bm_ret    = spy_bm_ret[sim_start:sim_end]
spy_bm_ret[0] = 0.0 # Normalize benchmark returns to start at 0.0.
perf          = perf[sim_start:sim_end]

returns, positions, transactions = pf.utils.extract_rets_pos_txn_from_zipline(perf)
#pf.create_txn_tear_sheet(returns, positions=positions, transactions=transactions)
#pf.create_round_trip_tear_sheet(returns, positions=positions, transactions=transactions)
pf.create_full_tear_sheet(returns, positions=positions, transactions=transactions, bootstrap=None,benchmark_rets=spy_bm_ret, round_trips=True)
#pf.create_simple_tear_sheet(returns=returns,positions=positions,transactions=transactions,benchmark_rets=spy_bm_ret)
# Out:
# Entire data start date: 2019-04-02
# Entire data end date: 2021-05-19
# Backtest months: 25
#                     Backtest
# Annual return          25.1%
# Cumulative returns     61.4%
# Annual volatility      28.5%
# Sharpe ratio            0.93
# Calmar ratio            0.69
# Stability               0.51
# Max drawdown          -36.3%
# Omega ratio             1.20
# Sortino ratio           1.33
# Skew                   -0.39
# Kurtosis                6.22
# Tail ratio              1.05
# Daily value at risk    -3.5%
# Gross leverage          1.00
# Daily turnover          2.2%
# Alpha                   0.08
# Beta                    0.92
# Worst drawdown periods Net drawdown in %  Peak date Valley date Recovery date  \
# 0                                  36.34 2019-12-23  2020-03-23    2020-06-03
# 1                                  22.03 2020-06-08  2020-07-13    2020-10-23
# 2                                   8.63 2019-05-03  2019-05-31    2019-07-01
# 3                                   8.22 2019-07-26  2019-08-27    2019-12-12
# 4                                   6.37 2021-02-08  2021-02-26    2021-03-10
#
# Worst drawdown periods Duration
# 0                           118
# 1                           100
# 2                            42
# 3                           100
# 4                            23
# Stress Events  mean    min   max
# New Normal    0.10% -9.56% 8.60%
# Top 10 long positions of all time    max
# PG                                51.91%
# CLDR                              50.42%
# HWM                               23.29%
# MGM                               22.34%
# COF                               21.21%
# DD                                21.18%
# FE                                21.08%
# MRNA                              18.42%
# BLL                               17.16%
# A                                 17.04%
# Empty DataFrame
# Columns: [max]
# Index: []
# Top 10 positions of all time    max
# PG                           51.91%
# CLDR                         50.42%
# HWM                          23.29%
# MGM                          22.34%
# COF                          21.21%
# DD                           21.18%
# FE                           21.08%
# MRNA                         18.42%
# BLL                          17.16%
# A                            17.04%
# All positions ever held    max
# PG                      51.91%
# CLDR                    50.42%
# HWM                     23.29%
# MGM                     22.34%
# COF                     21.21%
# DD                      21.18%
# FE                      21.08%
# MRNA                    18.42%
# BLL                     17.16%
# A                       17.04%
# OHI                     16.90%
# HUM                     16.58%
# CLNE                    14.87%
# LI                      14.16%
# PFE                     13.20%
# AVXL                    12.46%
# JBLU                    12.34%
# FSLR                    12.34%
# BABA                    12.27%
# CARG                    12.25%
# ODFL                    12.20%
# FOXA                    12.14%
# MUR                     12.14%
# NBR                     11.93%
# FOX                     11.71%
# GRA                     11.27%
# ORLY                    11.23%
# BWA                     11.07%
# INTU                    10.89%
# FNV                     10.87%
# AME                     10.85%
# PPG                     10.71%
# ADI                     10.70%
# CHKP                    10.58%
# AMCR                    10.56%
# INCY                    10.47%
# EMN                     10.31%
# MCO                     10.29%
# AIMT                    10.01%
# PFPT                     9.78%
# Summary stats                All trades  Long trades
# Total number of round_trips      137.00       137.00
# Percent profitable                 0.65         0.65
# Winning round_trips               89.00        89.00
# Losing round_trips                48.00        48.00
# Even round_trips                   0.00         0.00
# PnL stats                 All trades  Long trades
# Total profit               $30721.99    $30721.99
# Gross profit               $56254.66    $56254.66
# Gross loss                $-25532.68   $-25532.68
# Profit factor                  $2.20        $2.20
# Avg. trade net profit        $224.25      $224.25
# Avg. winning trade           $632.07      $632.07
# Avg. losing trade           $-531.93     $-531.93
# Ratio Avg. Win:Avg. Loss       $1.19        $1.19
# Largest winning trade       $4343.19     $4343.19
# Largest losing trade       $-2632.43    $-2632.43
# Duration stats                 All trades             Long trades
# Avg duration      68 days 19:52:59.635036 68 days 19:52:59.635036
# Median duration          60 days 23:00:00        60 days 23:00:00
# Longest duration        273 days 00:00:00       273 days 00:00:00
# Shortest duration        20 days 04:00:01        20 days 04:00:01
# Return stats                    All trades  Long trades
# Avg returns all round_trips          0.29%        0.29%
# Avg returns winning                  1.06%        1.06%
# Avg returns losing                  -1.14%       -1.14%
# Median returns all round_trips       0.13%        0.13%
# Median returns winning               0.58%        0.58%
# Median returns losing               -0.61%       -0.61%
# Largest winning trade                6.71%        6.71%
# Largest losing trade                -6.72%       -6.72%
# Symbol stats                        A   ADI   AIMT   AMCR   AME  AVXL   BABA  \
# Avg returns all round_trips     0.24% 1.91% -0.10%  0.12% 0.96% 1.07% -0.80%
# Avg returns winning             0.92% 1.91%   nan%  0.71% 0.96% 1.07%   nan%
# Avg returns losing             -0.44%  nan% -0.10% -1.07%  nan%  nan% -0.80%
# Median returns all round_trips  0.29% 1.91% -0.10%  0.47% 0.96% 1.07% -0.34%
# Median returns winning          0.90% 1.91%   nan%  0.71% 0.96% 1.07%   nan%
# Median returns losing          -0.22%  nan% -0.10% -1.07%  nan%  nan% -0.34%
# Largest winning trade           1.28% 1.91% -0.10%  0.95% 0.96% 1.07% -0.10%
# Largest losing trade           -1.11% 1.91% -0.10% -1.07% 0.96% 1.07% -1.94%
#
# Symbol stats                      BLL    BWA  CARG  CHKP   CLDR  CLNE    COF  \
# Avg returns all round_trips     0.54% -0.32% 3.43% 0.37% -1.58% 2.32%  0.02%
# Avg returns winning             1.00%  2.91% 3.43% 0.37%  0.10% 2.32%  1.44%
# Avg returns losing             -0.85% -1.40%  nan%  nan% -2.14%  nan% -2.11%
# Median returns all round_trips  0.63% -1.01% 3.43% 0.37% -1.33% 2.32%  0.24%
# Median returns winning          1.05%  2.91% 3.43% 0.37%  0.10% 2.32%  0.70%
# Median returns losing          -0.85% -1.66%  nan%  nan% -1.74%  nan% -1.03%
# Largest winning trade           1.75%  2.91% 3.43% 0.37%  0.16% 2.32%  3.80%
# Largest losing trade           -0.85% -2.18% 3.43% 0.37% -4.74% 2.32% -5.92%
#
# Symbol stats                       DD   EMN     FE   FNV    FOX  FOXA  FSLR  \
# Avg returns all round_trips     0.63% 0.02% -0.06% 2.76% -0.79% 0.42% 2.01%
# Avg returns winning             0.86% 0.02%  0.40% 2.76%  0.15% 0.42% 2.01%
# Avg returns losing             -0.36%  nan% -1.46%  nan% -2.68%  nan%  nan%
# Median returns all round_trips  0.19% 0.02%  0.10% 2.76%  0.07% 0.43% 2.01%
# Median returns winning          0.22% 0.02%  0.15% 2.76%  0.15% 0.43% 2.01%
# Median returns losing          -0.36%  nan% -1.46%  nan% -2.68%  nan%  nan%
# Largest winning trade           3.72% 0.02%  1.64% 2.76%  0.23% 0.79% 3.27%
# Largest losing trade           -0.70% 0.02% -2.43% 2.76% -2.68% 0.04% 0.76%
#
# Symbol stats                      GRA   HUM    HWM   INCY  INTU   JBLU    LI  \
# Avg returns all round_trips    -0.30% 0.38%  1.46% -0.32% 1.07% -0.13% 1.10%
# Avg returns winning              nan% 0.38%  1.67%   nan% 1.07%  1.21% 1.10%
# Avg returns losing             -0.30%  nan% -0.06% -0.32%  nan% -3.46%  nan%
# Median returns all round_trips -0.30% 0.38%  0.56% -0.32% 1.07%  0.04% 1.10%
# Median returns winning           nan% 0.38%  1.02%   nan% 1.07%  0.13% 1.10%
# Median returns losing          -0.30%  nan% -0.06% -0.32%  nan% -3.46%  nan%
# Largest winning trade          -0.01% 0.38%  6.71% -0.32% 1.07%  4.74% 1.10%
# Largest losing trade           -0.58% 0.38% -0.06% -0.32% 1.07% -6.72% 1.10%
#
# Symbol stats                      MCO    MGM  MRNA    MUR   NBR   ODFL    OHI  \
# Avg returns all round_trips    -0.49%  0.52% 2.08%  0.75% 2.62% -0.31%  0.05%
# Avg returns winning              nan%  1.56% 2.08%  1.49% 2.62%   nan%  0.38%
# Avg returns losing             -0.49% -1.04%  nan% -0.73%  nan% -0.31% -2.22%
# Median returns all round_trips -0.49%  0.01% 1.50%  1.23% 2.62% -0.31%  0.28%
# Median returns winning           nan%  1.90% 1.50%  1.49% 2.62%   nan%  0.40%
# Median returns losing          -0.49% -1.04%  nan% -0.73%  nan% -0.31% -2.22%
# Largest winning trade          -0.49%  2.76% 4.86%  1.74% 2.62% -0.31%  0.82%
# Largest losing trade           -0.49% -1.28% 0.45% -0.73% 2.62% -0.31% -2.22%
#
# Symbol stats                     ORLY    PFE   PFPT     PG    PPG
# Avg returns all round_trips     0.78%  0.21% -0.08% -0.20%  0.31%
# Avg returns winning             1.74%  0.28%   nan%  0.35%  1.12%
# Avg returns losing             -0.19% -0.17% -0.08% -0.52% -0.50%
# Median returns all round_trips  0.78%  0.04% -0.08% -0.10%  0.31%
# Median returns winning          1.74%  0.04%   nan%  0.35%  1.12%
# Median returns losing          -0.19% -0.17% -0.08% -0.24% -0.50%
# Largest winning trade           1.74%  0.75% -0.08%  0.69%  1.12%
# Largest losing trade           -0.19% -0.17% -0.08% -1.55% -0.50%
# Profitability (PnL / PnL total) per name
# symbol
# HWM                                       23.22%
# MRNA                                      13.84%
# DD                                        13.09%
# COF                                        8.34%
# FSLR                                       8.24%
# JBLU                                       6.05%
# MUR                                        5.56%
# CLNE                                       5.46%
# CARG                                       5.31%
# MGM                                        4.09%
# NBR                                        4.05%
# ADI                                        4.02%
# FNV                                        4.01%
# BLL                                        3.82%
# FOXA                                       3.10%
# INTU                                       2.69%
# AVXL                                       2.67%
# PFE                                        2.58%
# LI                                         2.48%
# A                                          2.33%
# ORLY                                       2.24%
# PPG                                        2.01%
# AMCR                                       1.58%
# AME                                        1.48%
# OHI                                        1.30%
# HUM                                        0.61%
# CHKP                                       0.60%
# EMN                                        0.04%
# AIMT                                      -0.16%
# PFPT                                      -0.21%
# ODFL                                      -0.48%
# FE                                        -0.50%
# INCY                                      -0.50%
# MCO                                       -0.75%
# GRA                                       -0.92%
# PG                                        -1.64%
# BWA                                       -1.99%
# FOX                                       -3.36%
# BABA                                      -3.61%
# CLDR                                     -20.68%

# %%
#positions
