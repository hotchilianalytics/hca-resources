# %%
# %%html
# <style>
#     table {margin-left: 0 } !important;}
# </style>
# <style type="text/css">
#     table.dataframe td, table.dataframe th {border: 1px solid lightgray;}
# </style>
# Out:
# <style>
#     table {margin-left: 0 } !important;}
# </style>
# <style type="text/css">
#     table.dataframe td, table.dataframe th {border: 1px solid lightgray;}
# </style>

# %% [markdown]
# <img src="http://drive.google.com/uc?export=view&id=1zJjN-vEjutF__7wpEq5Yibxv9BRZeC74"
#      alt="HCA Logo" height="150" width="150"
#      style="float: left; margin-right: 10px;">
#
# |Name  | Value |
# | :- |:-------------: |
# | Notebook:  | HotChili Trader Tear Sheet |
# | Version:  | 2.0.0 |
# | Date:  | 2020-04-16  |
# | Copyright:  | @2019-2021 |
# | Company:  | HotChili Analytics, LLC |
# | Authors   :  | Alan & Jeff Coppola |

# %%
import pandas as pd
import numpy as np
import matplotlib as mp
import matplotlib.pyplot as plt
import pyfolio as pf
# %matplotlib inline

# silence warnings
import warnings
warnings.filterwarnings('ignore')
### %pylab inline
###figsize(12, 12)
# Out:
# WARNING (theano.configdefaults): install mkl with `conda install mkl-service`: No module named 'mkl'
# /home/hca-r2-001/miniconda3/envs/hca/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %%
pd.set_option("max_colwidth", 400)
pd.set_option("display.max_rows", 100000)
pd.set_option("display.max_columns", 1000)
pd.set_option('precision', 2)
pd.options.display.float_format = '{:20,.2f}'.format

# %%
# Parameters for location of zipline-broker run
#hca/hca-resources/HCA_Fundamentals/fund_bt.pkl
#hca/hca-resources/HCA_Fundamentals/fund_bt.pkl
nb_dir = "/home/hca-ws2004/hca/hca-resources/HCA_Fundamentals/"
ans_pkl = "HCA_Ftest.pkl"
#ans_pkl = "HCA_Fundamentals_Live.pkl"
ans_data_file = nb_dir + ans_pkl

# Read in backtest results for analysis
perf=pd.read_pickle(ans_data_file)

# %%
perf.columns
#dir(perf)
# Out:
# Index(['algo_volatility', 'algorithm_period_return', 'alpha',
#        'benchmark_period_return', 'benchmark_volatility', 'beta',
#        'capital_used', 'ending_cash', 'ending_exposure', 'ending_value',
#        'excess_return', 'gross_leverage', 'leverage', 'long_count',
#        'long_exposure', 'long_value', 'longs_count', 'max_drawdown',
#        'max_leverage', 'net_leverage', 'orders', 'period_close',
#        'period_label', 'period_open', 'pnl', 'port_wts', 'portfolio_value',
#        'positions', 'returns', 'sharpe', 'short_count', 'short_exposure',
#        'short_value', 'shorts_count', 'sortino', 'starting_cash',
#        'starting_exposure', 'starting_value', 'trading_days', 'transactions',
#        'treasury_period_return'],
#       dtype='object')

# %%
perf.shape
# Out:
# (539, 41)

# %%
import pandas as pd
returns, positions, transactions= pf.utils.extract_rets_pos_txn_from_zipline(perf)

# %%
#positions

# %%
#transactions

# %%
import sys

print("Tear Sheet File : {}".format(ans_data_file))
print("-----------------------------------")
print("Python version={}".format(sys.version))
print("Matplotlib version={}".format(mp.__version__))
print("Numpy version={}".format(np.version.version))
# Out:
# Tear Sheet File : /home/hca-ws2004/hca/hca-resources/HCA_Fundamentals/HCA_Ftest.pkl
# -----------------------------------
# Python version=3.6.7 |Anaconda, Inc.| (default, Oct 23 2018, 19:16:44)
# [GCC 7.3.0]
# Matplotlib version=3.1.1
# Numpy version=1.14.0

# %%
#pf.plot_drawdown_periods(returns, top=5).set_xlabel('Date')

# %%
#returns.plot()

# %%
#transactions

# %%
#from datetime import datetime
#import pytz
#start = datetime(2017, 2, 11, 0, 0, 0, 0, pytz.utc)
#end = datetime(2019, 3, 14, 0, 0, 0, 0, pytz.utc)
#s=pd.Timestamp(start)

# %%
#pf.create_position_tear_sheet(returns=returns,positions=positions)
#pf.plot_perf_stats(returns= returns, factor_returns=returns)

# %%
sim_start=perf.index[0]
sim_end= perf.index[-1]
print("start={}  end={}".format(sim_start,sim_end))
# Out:
# start=2019-04-01 00:00:00+00:00  end=2021-05-19 00:00:00+00:00

# %%
#%%pixie_debugger

from zipline.data import benchmarks
# Set up benchmark Asset 
spy_bm_ret    = benchmarks.get_benchmark_returns(symbol='SPY', first_date=sim_start, last_date=sim_end)
spy_bm_ret    = spy_bm_ret[sim_start:sim_end]
spy_bm_ret[0] = 0.0 # Normalize benchmark returns to start at 0.0.
perf          = perf[sim_start:sim_end]

returns, positions, transactions = pf.utils.extract_rets_pos_txn_from_zipline(perf)
#pf.create_txn_tear_sheet(returns, positions=positions, transactions=transactions)
#pf.create_round_trip_tear_sheet(returns, positions=positions, transactions=transactions)
pf.create_full_tear_sheet(returns, positions=positions, transactions=transactions, bootstrap=None,benchmark_rets=spy_bm_ret, round_trips=True)
#pf.create_simple_tear_sheet(returns=returns,positions=positions,transactions=transactions,benchmark_rets=spy_bm_ret)
# Out:
# Entire data start date: 2019-04-02
# Entire data end date: 2021-05-19
# Backtest months: 25
#                     Backtest
# Annual return          20.5%
# Cumulative returns     48.9%
# Annual volatility      37.7%
# Sharpe ratio            0.69
# Calmar ratio            0.49
# Stability               0.30
# Max drawdown          -42.0%
# Omega ratio             1.13
# Sortino ratio           0.96
# Skew                   -0.59
# Kurtosis                4.82
# Tail ratio              1.03
# Daily value at risk    -4.6%
# Gross leverage          1.00
# Daily turnover          1.3%
# Alpha                   0.03
# Beta                    1.13
# Worst drawdown periods Net drawdown in %  Peak date Valley date Recovery date  \
# 0                                  42.00 2020-01-17  2020-03-23    2021-01-06
# 1                                  13.30 2019-07-24  2019-08-15    2019-10-07
# 2                                  12.89 2021-02-17  2021-03-04           NaT
# 3                                   9.42 2019-05-06  2019-05-31    2019-06-20
# 4                                   7.04 2021-01-27  2021-01-29    2021-02-04
#
# Worst drawdown periods Duration
# 0                           254
# 1                            54
# 2                           NaN
# 3                            34
# 4                             7
# Stress Events  mean     min   max
# New Normal    0.10% -13.20% 8.56%
# Top 10 long positions of all time    max
# FOSL                              19.49%
# MODV                              16.73%
# GOTU                              16.46%
# DFS                               16.34%
# CFG                               16.02%
# NUE                               15.85%
# FRO                               15.75%
# CLB                               15.74%
# GLT                               15.48%
# CY                                15.48%
# Empty DataFrame
# Columns: [max]
# Index: []
# Top 10 positions of all time    max
# FOSL                         19.49%
# MODV                         16.73%
# GOTU                         16.46%
# DFS                          16.34%
# CFG                          16.02%
# NUE                          15.85%
# FRO                          15.75%
# CLB                          15.74%
# GLT                          15.48%
# CY                           15.48%
# All positions ever held    max
# FOSL                    19.49%
# MODV                    16.73%
# GOTU                    16.46%
# DFS                     16.34%
# CFG                     16.02%
# NUE                     15.85%
# FRO                     15.75%
# CLB                     15.74%
# GLT                     15.48%
# CY                      15.48%
# EVRI                    15.09%
# KT                      14.75%
# CURO                    14.74%
# LOMA                    14.06%
# KIDS                    14.05%
# NVMI                    13.66%
# ELY                     13.58%
# ATNX                    13.58%
# PDSB                    13.46%
# MPNGY                   13.40%
# EYEG                    13.33%
# CSFL                    13.13%
# BNTX                    13.01%
# NBHC                    12.84%
# CLGX                    12.75%
# BTCM                    12.31%
# FBIO                    12.15%
# NGG                     12.01%
# NLOK                    11.60%
# KMPR                    11.54%
# CIG                     11.47%
# FFIN                    11.29%
# ISRG                    11.17%
# ATEC                    11.13%
# CI                      11.01%
# AIMC                    10.87%
# ATEX                    10.84%
# EAF                     10.74%
# ADI                     10.62%
# CQP                     10.53%
# KAIR                    10.51%
# HTLF                    10.50%
# APSG                    10.36%
# ASPS                    10.33%
# CNOB                    10.27%
# FNB                     10.26%
# CXP                     10.12%
# EXPR                    10.03%
# AXSM                     9.97%
# ERES                     9.83%
# Summary stats                All trades  Long trades
# Total number of round_trips      125.00       125.00
# Percent profitable                 0.64         0.64
# Winning round_trips               80.00        80.00
# Losing round_trips                45.00        45.00
# Even round_trips                   0.00         0.00
# PnL stats                 All trades  Long trades
# Total profit               $24529.26    $24529.26
# Gross profit               $56011.09    $56011.09
# Gross loss                $-31481.83   $-31481.83
# Profit factor                  $1.78        $1.78
# Avg. trade net profit        $196.23      $196.23
# Avg. winning trade           $700.14      $700.14
# Avg. losing trade           $-699.60     $-699.60
# Ratio Avg. Win:Avg. Loss       $1.00        $1.00
# Largest winning trade       $5153.52     $5153.52
# Largest losing trade       $-4350.09    $-4350.09
# Duration stats                  All trades              Long trades
# Avg duration      121 days 22:39:21.680000 121 days 22:39:21.680000
# Median duration           91 days 00:00:00         91 days 00:00:00
# Longest duration         546 days 01:00:00        546 days 01:00:00
# Shortest duration         20 days 04:00:01         20 days 04:00:01
# Return stats                    All trades  Long trades
# Avg returns all round_trips          0.24%        0.24%
# Avg returns winning                  1.13%        1.13%
# Avg returns losing                  -1.35%       -1.35%
# Median returns all round_trips       0.05%        0.05%
# Median returns winning               0.41%        0.41%
# Median returns losing               -0.67%       -0.67%
# Largest winning trade                6.76%        6.76%
# Largest losing trade                -7.03%       -7.03%
# Symbol stats                     ADI   AIMC   APSG   ASPS   ATEC  ATEX  ATNX  \
# Avg returns all round_trips    1.16% -2.14% -0.23% -1.09% -7.03% 1.72% 1.98%
# Avg returns winning            1.16%   nan%   nan%   nan%   nan% 1.72% 1.98%
# Avg returns losing              nan% -2.14% -0.23% -1.09% -7.03%  nan%  nan%
# Median returns all round_trips 1.16% -2.14% -0.23% -1.09% -7.03% 1.72% 1.02%
# Median returns winning         1.16%   nan%   nan%   nan%   nan% 1.72% 1.02%
# Median returns losing           nan% -2.14% -0.23% -1.09% -7.03%  nan%  nan%
# Largest winning trade          2.26% -0.00% -0.23% -1.09% -7.03% 1.72% 4.12%
# Largest losing trade           0.06% -4.27% -0.23% -1.09% -7.03% 1.72% 0.79%
#
# Symbol stats                     AXSM   BNTX   BTCM    CFG     CI    CIG  \
# Avg returns all round_trips    -0.28% -1.34% -5.71%  0.47% -0.03% -1.76%
# Avg returns winning              nan%   nan%   nan%  0.96%  0.02%   nan%
# Avg returns losing             -0.28% -1.34% -5.71% -0.68% -0.07% -1.76%
# Median returns all round_trips -0.28% -1.34% -5.71%  0.08% -0.03% -1.76%
# Median returns winning           nan%   nan%   nan%  0.22%  0.02%   nan%
# Median returns losing          -0.28% -1.34% -5.71% -0.35% -0.07% -1.76%
# Largest winning trade          -0.28% -1.34% -5.71%  5.33%  0.02% -1.76%
# Largest losing trade           -0.28% -1.34% -5.71% -1.60% -0.07% -1.76%
#
# Symbol stats                      CLB   CLGX   CNOB    CQP   CSFL  CURO  \
# Avg returns all round_trips    -0.15% -0.32% -1.32% -0.10% -0.73% 2.07%
# Avg returns winning             0.17%  0.25%   nan%  0.03%  0.06% 2.07%
# Avg returns losing             -0.81% -3.76% -1.32% -0.35% -1.13%  nan%
# Median returns all round_trips  0.12%  0.04% -1.32%  0.01% -0.02% 2.07%
# Median returns winning          0.17%  0.06%   nan%  0.03%  0.06% 2.07%
# Median returns losing          -0.81% -3.76% -1.32% -0.35% -1.13%  nan%
# Largest winning trade           0.23%  1.15% -1.32%  0.05%  0.06% 4.11%
# Largest losing trade           -0.81% -3.76% -1.32% -0.35% -2.25% 0.02%
#
# Symbol stats                      CXP     CY    DFS    EAF   ELY   ERES  \
# Avg returns all round_trips    -0.56% -0.04%  1.07% -2.19% 0.72%  0.09%
# Avg returns winning              nan%   nan%  1.28%   nan% 0.72%  0.18%
# Avg returns losing             -0.56% -0.04% -0.00% -2.19%  nan% -0.00%
# Median returns all round_trips -0.56% -0.00%  0.61% -2.19% 0.01%  0.09%
# Median returns winning           nan%   nan%  0.63%   nan% 0.01%  0.18%
# Median returns losing          -0.56% -0.00% -0.00% -2.19%  nan% -0.00%
# Largest winning trade          -0.56% -0.00%  4.11% -2.19% 2.15%  0.18%
# Largest losing trade           -0.56% -0.12% -0.00% -2.19% 0.00% -0.00%
#
# Symbol stats                     EVRI   EXPR   EYEG   FBIO  FFIN    FNB  FOSL  \
# Avg returns all round_trips    -0.32% -2.52% -0.93% -0.67% 0.31% -0.39% 3.48%
# Avg returns winning             3.56%   nan%  0.28%   nan% 0.31%   nan% 3.48%
# Avg returns losing             -2.26% -2.52% -2.75% -0.67%  nan% -0.39%  nan%
# Median returns all round_trips -1.29% -2.52%  0.13% -0.67% 0.31% -0.39% 3.48%
# Median returns winning          3.56%   nan%  0.16%   nan% 0.31%   nan% 3.48%
# Median returns losing          -2.26% -2.52% -2.75% -0.67%  nan% -0.39%  nan%
# Largest winning trade           3.56% -2.52%  0.56% -0.67% 0.61% -0.39% 5.47%
# Largest losing trade           -3.23% -2.52% -5.48% -0.67% 0.00% -0.39% 1.48%
#
# Symbol stats                      FRO    GLT  GOTU  HTLF  ISRG  KAIR  KIDS  \
# Avg returns all round_trips    -0.12% -0.18% 2.31% 0.06% 1.09% 0.03% 1.33%
# Avg returns winning             0.52%  0.81% 2.31% 0.06% 1.09% 0.03% 1.33%
# Avg returns losing             -1.07% -2.16%  nan%  nan%  nan%  nan%  nan%
# Median returns all round_trips  0.27%  0.02% 1.47% 0.06% 1.09% 0.03% 1.33%
# Median returns winning          0.38%  0.81% 1.47% 0.06% 1.09% 0.03% 1.33%
# Median returns losing          -1.07% -2.16%  nan%  nan%  nan%  nan%  nan%
# Largest winning trade           0.90%  1.61% 5.88% 0.09% 1.09% 0.03% 2.44%
# Largest losing trade           -1.34% -2.16% 0.34% 0.03% 1.09% 0.03% 0.21%
#
# Symbol stats                     KMPR     KT   LOMA  MODV  MPNGY   NBHC  \
# Avg returns all round_trips    -0.72% -0.13% -1.31% 1.37%  0.21% -1.67%
# Avg returns winning              nan%   nan%   nan% 1.37%  0.21%   nan%
# Avg returns losing             -0.72% -0.13% -1.31%  nan%   nan% -1.67%
# Median returns all round_trips -0.72% -0.13% -1.31% 0.73%  0.13% -1.67%
# Median returns winning           nan%   nan%   nan% 0.73%  0.13%   nan%
# Median returns losing          -0.72% -0.13% -1.31%  nan%   nan% -1.67%
# Largest winning trade          -0.72% -0.10% -0.28% 4.03%  0.38% -0.01%
# Largest losing trade           -0.72% -0.16% -2.34% 0.00%  0.13% -3.32%
#
# Symbol stats                      NGG  NLOK   NUE   NVMI  PDSB
# Avg returns all round_trips    -0.39% 1.82% 1.89%  1.16% 1.12%
# Avg returns winning              nan% 1.82% 1.89%  1.50% 1.12%
# Avg returns losing             -0.39%  nan%  nan% -0.21%  nan%
# Median returns all round_trips -0.39% 1.82% 0.59%  0.20% 1.12%
# Median returns winning           nan% 1.82% 0.59%  1.53% 1.12%
# Median returns losing          -0.39%  nan%  nan% -0.21%  nan%
# Largest winning trade          -0.39% 1.82% 6.76%  2.92% 1.64%
# Largest losing trade           -0.39% 1.82% 0.01% -0.21% 0.61%
# Profitability (PnL / PnL total) per name
# symbol
# GOTU                                      29.30%
# NUE                                       28.44%
# FOSL                                      20.61%
# DFS                                       17.49%
# CFG                                       16.56%
# MODV                                      13.02%
# NVMI                                      12.67%
# ATNX                                      12.37%
# CURO                                       7.95%
# PDSB                                       6.91%
# ADI                                        6.78%
# KIDS                                       6.37%
# NLOK                                       5.65%
# ELY                                        4.85%
# ATEX                                       4.28%
# ISRG                                       3.40%
# FFIN                                       1.91%
# MPNGY                                      1.83%
# ERES                                       0.45%
# HTLF                                       0.24%
# KAIR                                       0.09%
# CI                                        -0.11%
# GLT                                       -0.19%
# CY                                        -0.22%
# KT                                        -0.51%
# APSG                                      -0.64%
# NGG                                       -0.76%
# FNB                                       -0.77%
# FRO                                       -0.79%
# AXSM                                      -0.88%
# CLB                                       -0.88%
# CQP                                       -0.95%
# EVRI                                      -1.09%
# CXP                                       -1.11%
# KMPR                                      -1.39%
# FBIO                                      -1.66%
# CLGX                                      -2.08%
# ASPS                                      -2.16%
# BNTX                                      -2.60%
# CNOB                                      -3.15%
# CSFL                                      -4.95%
# CIG                                       -5.30%
# EXPR                                      -5.33%
# EAF                                       -5.36%
# NBHC                                      -6.04%
# LOMA                                      -6.19%
# EYEG                                      -7.58%
# AIMC                                      -8.22%
# ATEC                                     -12.52%
# BTCM                                     -17.73%

# %%
#positions
