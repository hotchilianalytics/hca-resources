# %%
# %%html
# <style>
#   table {margin-left: 0 !important;}
# </style>
# Out:
# <style>
#   table {margin-left: 0 !important;}
# </style>

# %% [markdown]
# <img src="http://drive.google.com/uc?export=view&id=1zJjN-vEjutF__7wpEq5Yibxv9BRZeC74"
#      alt="HCA Logo" height="150" width="150"
#      style="float: left; margin-right: 10px;">
#
# |Name  | Value |
# | :- |:-------------: |
# | **Notebook:**  | **HotChili Trader Tear Sheet** |
# | **Version:**  | 1.0.1c |
# | **Date:**  | 2020-08-06  |
# | **Copyright:**  | @2019-2020 |
# | **Company:**  | **HotChili Analytics, LLC** |
# | **Author   :**  | Alan Coppola|(ajjcoppola@hotchilianalytics.com) |
# | **Author   :**  | Jeff Coppola|(jeff@hotchilianalytics.com) |

# %%
import pandas as pd
import numpy as np
import matplotlib as mp
import matplotlib.pyplot as plt
import pyfolio as pf
# %matplotlib inline

# silence warnings
import warnings
warnings.filterwarnings('ignore')
### %pylab inline
###figsize(12, 12)
# Out:
# WARNING (theano.configdefaults): install mkl with `conda install mkl-service`: No module named 'mkl'
# /home/hca-r2-001/miniconda3/envs/hca/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %%
pd.set_option("max_colwidth", 400)
pd.set_option("display.max_rows", 100000)
pd.set_option("display.max_columns", 1000)
pd.set_option('precision', 2)
pd.options.display.float_format = '{:20,.2f}'.format

# %%
# Parameters for location of zipline-broker run
#hca/hca-resources/HCA_Fundamentals/fund_bt.pkl
#hca/hca-resources/HCA_Fundamentals/fund_bt.pkl
nb_dir = "/home/hca-ws2004/hca/hca-resources/HCA_Fundamentals/"
ans_pkl = "HCA_Fundamentals.pkl"
ans_data_file = nb_dir + ans_pkl

# Read in backtest results for analysis
perf=pd.read_pickle(ans_data_file)

# %%
perf.columns
#dir(perf)
# Out:
# Index(['algo_volatility', 'algorithm_period_return', 'alpha',
#        'benchmark_period_return', 'benchmark_volatility', 'beta',
#        'capital_used', 'ending_cash', 'ending_exposure', 'ending_value',
#        'excess_return', 'gross_leverage', 'leverage', 'long_count',
#        'long_exposure', 'long_value', 'longs_count', 'max_drawdown',
#        'max_leverage', 'net_leverage', 'orders', 'period_close',
#        'period_label', 'period_open', 'pnl', 'port_wts', 'portfolio_value',
#        'positions', 'returns', 'sharpe', 'short_count', 'short_exposure',
#        'short_value', 'shorts_count', 'sortino', 'starting_cash',
#        'starting_exposure', 'starting_value', 'trading_days', 'transactions',
#        'treasury_period_return'],
#       dtype='object')

# %%
perf.shape
# Out:
# (511, 41)

# %%
import pandas as pd
returns, positions, transactions= pf.utils.extract_rets_pos_txn_from_zipline(perf)

# %%
#positions

# %%
#transactions

# %%
import sys

print("Tear Sheet File : {}".format(ans_data_file))
print("-----------------------------------")
print("Python version={}".format(sys.version))
print("Matplotlib version={}".format(mp.__version__))
print("Numpy version={}".format(np.version.version))
# Out:
# Tear Sheet File : /home/hca-ws2004/hca/hca-resources/HCA_Fundamentals/HCA_Fundamentals.pkl
# -----------------------------------
# Python version=3.6.7 |Anaconda, Inc.| (default, Oct 23 2018, 19:16:44)
# [GCC 7.3.0]
# Matplotlib version=3.1.1
# Numpy version=1.14.0

# %%
#pf.plot_drawdown_periods(returns, top=5).set_xlabel('Date')

# %%
#returns.plot()

# %%
#transactions

# %%
#from datetime import datetime
#import pytz
#start = datetime(2017, 2, 11, 0, 0, 0, 0, pytz.utc)
#end = datetime(2019, 3, 14, 0, 0, 0, 0, pytz.utc)
#s=pd.Timestamp(start)

# %%
#pf.create_position_tear_sheet(returns=returns,positions=positions)
#pf.plot_perf_stats(returns= returns, factor_returns=returns)

# %%
sim_start=perf.index[0]
sim_end= perf.index[-1]
print("start={}  end={}".format(sim_start,sim_end))
# Out:
# start=2019-04-01 00:00:00+00:00  end=2021-04-09 00:00:00+00:00

# %%
#%%pixie_debugger

from zipline.data import benchmarks
# Set up benchmark Asset 
spy_bm_ret    = benchmarks.get_benchmark_returns(symbol='SPY', first_date=sim_start, last_date=sim_end)
spy_bm_ret    = spy_bm_ret[sim_start:sim_end]
spy_bm_ret[0] = 0.0 # Normalize benchmark returns to start at 0.0.
perf          = perf[sim_start:sim_end]

returns, positions, transactions = pf.utils.extract_rets_pos_txn_from_zipline(perf)
#pf.create_txn_tear_sheet(returns, positions=positions, transactions=transactions)
#pf.create_round_trip_tear_sheet(returns, positions=positions, transactions=transactions)
pf.create_full_tear_sheet(returns, positions=positions, transactions=transactions, bootstrap=None,benchmark_rets=spy_bm_ret, round_trips=True)
#pf.create_simple_tear_sheet(returns=returns,positions=positions,transactions=transactions,benchmark_rets=spy_bm_ret)
# Out:
# Entire data start date: 2019-04-02
# Entire data end date: 2021-04-09
# Backtest months: 24
#                     Backtest
# Annual return          32.7%
# Cumulative returns     77.3%
# Annual volatility      33.9%
# Sharpe ratio            1.01
# Calmar ratio            0.89
# Stability               0.81
# Max drawdown          -36.6%
# Omega ratio             1.22
# Sortino ratio           1.45
# Skew                   -0.53
# Kurtosis               10.68
# Tail ratio              1.24
# Daily value at risk    -4.1%
# Gross leverage          0.89
# Daily turnover          8.2%
# Alpha                   0.11
# Beta                    1.13
# Worst drawdown periods Net drawdown in %  Peak date Valley date Recovery date  \
# 0                                  36.64 2020-01-17  2020-03-23    2020-05-26
# 1                                  18.45 2019-04-10  2019-05-31    2019-11-05
# 2                                   9.24 2020-07-09  2020-09-08    2020-09-14
# 3                                   8.32 2021-02-19  2021-03-04           NaT
# 4                                   7.34 2020-06-05  2020-06-11    2020-07-02
#
# Worst drawdown periods Duration
# 0                            93
# 1                           150
# 2                            48
# 3                           NaN
# 4                            20
# Stress Events  mean     min   max
# New Normal    0.14% -16.02% 9.96%
# Top 10 long positions of all time    max
# EQNR                              36.77%
# FOLD                              33.74%
# HD                                33.20%
# CVNA                              32.12%
# IMMU                              31.52%
# GILD                              31.20%
# ADI                               30.90%
# MU                                29.63%
# ATVI                              28.72%
# NVO                               25.55%
# Top 10 short positions of all time    max
# GTXMQ                              -1.73%
# Top 10 positions of all time    max
# EQNR                         36.77%
# FOLD                         33.74%
# HD                           33.20%
# CVNA                         32.12%
# IMMU                         31.52%
# GILD                         31.20%
# ADI                          30.90%
# MU                           29.63%
# ATVI                         28.72%
# NVO                          25.55%
# All positions ever held    max
# EQNR                    36.77%
# FOLD                    33.74%
# HD                      33.20%
# CVNA                    32.12%
# IMMU                    31.52%
# GILD                    31.20%
# ADI                     30.90%
# MU                      29.63%
# ATVI                    28.72%
# NVO                     25.55%
# FIS                     25.27%
# ORCL                    24.41%
# JEF                     18.81%
# A                       18.57%
# CPRI                    18.07%
# LPX                     17.00%
# MGNX                    16.65%
# DFS                     16.65%
# GRUB                    16.26%
# FE                      16.23%
# GRFS                    14.43%
# CME                     14.39%
# BMRN                    14.15%
# BLDP                    13.45%
# GD                      13.04%
# HFC                     12.97%
# LCI                     12.80%
# HUN                     12.78%
# LOGM                    12.56%
# PLL                     12.50%
# FNB                     12.38%
# PLNT                    12.37%
# FND                     12.19%
# GRMN                    12.04%
# CF                      12.01%
# OAK                     12.00%
# AME                     11.94%
# PAYC                    11.66%
# PCAR                    11.53%
# INFY                    11.50%
# DKS                     11.44%
# BXP                     11.25%
# ALGN                    11.23%
# ALL                     11.16%
# CRSP                    11.11%
# CDEV                    11.03%
# AVLR                    10.99%
# LOW                     10.96%
# BITA                    10.79%
# AMED                    10.55%
# MIK                     10.46%
# NTR                     10.42%
# BRSS                    10.29%
# BURL                    10.24%
# HDS                     10.08%
# IPOE                    10.00%
# LVGO                     9.78%
# MBT                      9.61%
# MGY                      9.50%
# OMI                      9.33%
# GTXMQ                    9.27%
# FUTU                     9.24%
# NIU                      9.07%
# APPN                     8.90%
# GFI                      8.69%
# AA                       8.68%
# IDYA                     8.61%
# ENVA                     8.56%
# ALKS                     8.54%
# PFNX                     8.22%
# GPC                      8.12%
# BLNK                     8.09%
# PPBT                     8.05%
# KMX                      8.00%
# AZEK                     7.85%
# OCUL                     7.78%
# LIZI                     7.36%
# CSTE                     7.30%
# PDM                      7.27%
# GHVI                     7.25%
# MYOV                     7.04%
# ATHM                     6.80%
# AVID                     6.64%
# JIH                      6.57%
# CPSH                     6.44%
# AY                       6.43%
# CWEN                     6.22%
# COHR                     5.99%
# LH                       5.91%
# HEC                      5.83%
# KOPN                     5.38%
# LSEA                     4.29%
# Summary stats                All trades  Short trades  Long trades
# Total number of round_trips      765.00          8.00       757.00
# Percent profitable                 0.64          0.12         0.64
# Winning round_trips              489.00          1.00       488.00
# Losing round_trips               276.00          7.00       269.00
# Even round_trips                   0.00          0.00         0.00
# PnL stats                   All trades  Short trades   Long trades
# Total profit               $7759834.30      $4441.24   $7755393.06
# Gross profit              $22074225.55      $7863.51  $22066362.04
# Gross loss               $-14314391.24     $-3422.27 $-14310968.98
# Profit factor                    $1.54         $2.30         $1.54
# Avg. trade net profit        $10143.57       $555.15     $10244.90
# Avg. winning trade           $45141.57      $7863.51     $45217.95
# Avg. losing trade           $-51863.74      $-488.90    $-53200.63
# Ratio Avg. Win:Avg. Loss         $0.87        $16.08         $0.85
# Largest winning trade       $715393.25      $7863.51    $715393.25
# Largest losing trade       $-654614.96      $-500.04   $-654614.96
# Duration stats                 All trades           Short trades  \
# Avg duration      19 days 13:24:28.239215 1 days 02:29:59.125000
# Median duration          14 days 00:00:00        0 days 19:59:59
# Longest duration        112 days 01:00:00        3 days 00:00:00
# Shortest duration         0 days 19:59:59        0 days 19:59:59
#
# Duration stats                Long trades
# Avg duration      19 days 18:05:18.639365
# Median duration          14 days 00:00:00
# Longest duration        112 days 01:00:00
# Shortest duration         3 days 00:00:00
# Return stats                    All trades  Short trades  Long trades
# Avg returns all round_trips          0.06%         0.01%        0.06%
# Avg returns winning                  0.37%         0.07%        0.37%
# Avg returns losing                  -0.48%        -0.00%       -0.49%
# Median returns all round_trips       0.02%        -0.00%        0.02%
# Median returns winning               0.15%         0.07%        0.15%
# Median returns losing               -0.20%        -0.00%       -0.22%
# Largest winning trade                6.69%         0.07%        6.69%
# Largest losing trade                -6.58%        -0.00%       -6.58%
# Symbol stats                        A    AA    ADI   ALGN   ALKS    ALL  \
# Avg returns all round_trips     0.03% 0.23% -0.02% -0.35% -0.06%  0.07%
# Avg returns winning             0.18% 0.23%  0.18%   nan%  0.21%  0.22%
# Avg returns losing             -0.32%  nan% -0.42% -0.35% -0.33% -0.07%
# Median returns all round_trips  0.04% 0.10%  0.01% -0.36% -0.09% -0.00%
# Median returns winning          0.09% 0.10%  0.04%   nan%  0.21%  0.25%
# Median returns losing          -0.28%  nan% -0.20% -0.36% -0.33% -0.03%
# Largest winning trade           0.46% 0.54%  0.97% -0.03%  0.39%  0.47%
# Largest losing trade           -0.64% 0.02% -1.87% -0.65% -0.46% -0.18%
#
# Symbol stats                      AME   AMED   APPN  ATHM   ATVI  AVID   AVLR  \
# Avg returns all round_trips     0.11% -0.18% -0.76% 1.05%  0.12% 0.71% -0.00%
# Avg returns winning             0.28%   nan%   nan% 1.05%  0.25% 0.71%  0.12%
# Avg returns losing             -0.23% -0.18% -0.76%  nan% -0.15%  nan% -0.12%
# Median returns all round_trips  0.03% -0.18% -0.77% 1.05%  0.02% 0.71% -0.00%
# Median returns winning          0.28%   nan%   nan% 1.05%  0.05% 0.71%  0.12%
# Median returns losing          -0.23% -0.18% -0.77%  nan% -0.06%  nan% -0.12%
# Largest winning trade           0.53% -0.18% -0.11% 1.05%  0.67% 0.71%  0.12%
# Largest losing trade           -0.23% -0.18% -1.39% 1.05% -0.49% 0.71% -0.12%
#
# Symbol stats                       AY   AZEK   BITA   BLDP   BLNK   BMRN  \
# Avg returns all round_trips    -0.30% -0.13% -0.03% -0.03% -1.51% -0.96%
# Avg returns winning              nan%  0.09%  0.01%  0.33%   nan%   nan%
# Avg returns losing             -0.30% -0.35% -0.06% -0.67% -1.51% -0.96%
# Median returns all round_trips -0.30% -0.13% -0.02%  0.08% -0.77% -0.96%
# Median returns winning           nan%  0.09%  0.01%  0.21%   nan%   nan%
# Median returns losing          -0.30% -0.35% -0.06% -0.31% -0.77% -0.96%
# Largest winning trade          -0.30%  0.09%  0.01%  1.36% -0.00% -0.14%
# Largest losing trade           -0.30% -0.35% -0.10% -2.29% -3.77% -1.77%
#
# Symbol stats                     BRSS   BURL    BXP   CDEV     CF    CME  \
# Avg returns all round_trips    -0.00% -0.09% -0.05% -1.53% -0.27% -0.65%
# Avg returns winning              nan%   nan%  0.33%   nan%  0.07%   nan%
# Avg returns losing             -0.00% -0.09% -0.33% -1.53% -0.61% -0.65%
# Median returns all round_trips -0.00% -0.09% -0.06% -1.53% -0.01% -0.31%
# Median returns winning           nan%   nan%  0.04%   nan%  0.04%   nan%
# Median returns losing          -0.00% -0.09% -0.37% -1.53% -0.69% -0.31%
# Largest winning trade          -0.00% -0.09%  0.95% -1.53%  0.20% -0.14%
# Largest losing trade           -0.00% -0.09% -0.52% -1.53% -1.25% -2.02%
#
# Symbol stats                     COHR   CPRI  CPSH   CRSP   CSTE   CVNA  \
# Avg returns all round_trips    -0.14%  0.09% 0.95%  0.22%  0.00%  0.49%
# Avg returns winning              nan%  0.40% 0.95%  0.38%  0.02%  1.03%
# Avg returns losing             -0.14% -0.66%  nan% -0.21% -0.01% -0.75%
# Median returns all round_trips -0.14%  0.15% 0.95%  0.02% -0.00%  0.36%
# Median returns winning           nan%  0.28% 0.95%  0.11%  0.02%  0.61%
# Median returns losing          -0.14% -0.16%  nan% -0.12% -0.01% -0.73%
# Largest winning trade          -0.14%  1.34% 0.95%  1.50%  0.04%  6.69%
# Largest losing trade           -0.14% -2.88% 0.95% -0.43% -0.03% -1.58%
#
# Symbol stats                     CWEN    DFS    DKS  ENVA   EQNR     FE  \
# Avg returns all round_trips    -0.35%  0.23% -0.09% 0.51%  0.09% -1.04%
# Avg returns winning              nan%  0.46%  0.18% 0.51%  0.29%   nan%
# Avg returns losing             -0.35% -0.45% -0.27%  nan% -0.24% -1.04%
# Median returns all round_trips -0.35%  0.08% -0.08% 0.51%  0.00% -0.97%
# Median returns winning           nan%  0.15%  0.18% 0.51%  0.04%   nan%
# Median returns losing          -0.35% -0.34% -0.29%  nan% -0.10% -0.97%
# Largest winning trade          -0.35%  3.05%  0.32% 0.52%  1.40% -0.71%
# Largest losing trade           -0.35% -1.16% -0.45% 0.51% -1.55% -1.43%
#
# Symbol stats                      FIS    FNB    FND   FOLD   FUTU     GD  \
# Avg returns all round_trips     0.25% -0.04%  0.21%  0.23%  0.37%  0.00%
# Avg returns winning             0.41%  0.14%  0.50%  0.73%  0.83%  0.35%
# Avg returns losing             -0.12% -0.27% -0.36% -0.57% -0.46% -0.68%
# Median returns all round_trips  0.10%  0.00%  0.49%  0.18%  0.19%  0.34%
# Median returns winning          0.43%  0.08%  0.50%  0.67%  0.84%  0.35%
# Median returns losing          -0.10% -0.10% -0.36% -0.36% -0.61% -0.68%
# Largest winning trade           0.93%  0.54%  0.51%  1.77%  1.79%  0.35%
# Largest losing trade           -0.16% -1.39% -0.36% -1.30% -0.87% -0.68%
#
# Symbol stats                      GFI  GHVI   GILD   GPC  GRFS   GRMN   GRUB  \
# Avg returns all round_trips    -0.08% 0.21%  0.01% 0.14% 0.54% -0.09%  0.22%
# Avg returns winning             0.37% 0.21%  0.26% 0.14% 0.54%  0.29%  0.40%
# Avg returns losing             -0.38%  nan% -0.26%  nan%  nan% -0.46% -0.79%
# Median returns all round_trips -0.00% 0.04%  0.01% 0.14% 0.54% -0.03%  0.15%
# Median returns winning          0.37% 0.04%  0.13% 0.14% 0.54%  0.25%  0.19%
# Median returns losing          -0.47%  nan% -0.17%  nan%  nan% -0.33% -0.49%
# Largest winning trade           0.74% 0.57%  0.92% 0.14% 0.83%  0.49%  1.49%
# Largest losing trade           -0.67% 0.02% -0.76% 0.14% 0.25% -0.87% -1.52%
#
# Symbol stats                    GTXMQ     HD   HDS    HEC    HFC    HUN  \
# Avg returns all round_trips     0.02% -0.08% 0.06% -0.32%  0.01% -0.32%
# Avg returns winning             0.06%  0.15% 0.06%   nan%  0.18%  0.04%
# Avg returns losing             -0.02% -1.52%  nan% -0.32% -0.73% -0.51%
# Median returns all round_trips  0.01%  0.02% 0.01% -0.32%  0.03% -0.07%
# Median returns winning          0.06%  0.02% 0.01%   nan%  0.05%  0.04%
# Median returns losing          -0.02% -0.49%  nan% -0.32% -0.73% -0.51%
# Largest winning trade           0.07%  0.90% 0.17% -0.32%  1.11%  0.04%
# Largest losing trade           -0.02% -5.09% 0.00% -0.32% -1.42% -0.95%
#
# Symbol stats                     IDYA   IMMU   INFY   IPOE    JEF   JIH   KMX  \
# Avg returns all round_trips    -0.14%  0.46% -0.00%  0.58%  0.11% 0.13% 0.12%
# Avg returns winning              nan%  1.09%  0.17%  0.88%  0.26% 0.13% 0.12%
# Avg returns losing             -0.14% -1.17% -0.38% -0.61% -0.23%  nan%  nan%
# Median returns all round_trips -0.14%  0.04%  0.00%  0.10%  0.04% 0.13% 0.12%
# Median returns winning           nan%  0.44%  0.05%  0.11%  0.17% 0.13% 0.12%
# Median returns losing          -0.14% -0.71% -0.04% -0.61% -0.16%  nan%  nan%
# Largest winning trade          -0.14%  3.98%  0.54%  3.31%  1.19% 0.17% 0.12%
# Largest losing trade           -0.14% -3.17% -1.00% -0.61% -0.78% 0.08% 0.12%
#
# Symbol stats                     KOPN   LCI     LH   LIZI   LOGM    LOW  \
# Avg returns all round_trips    -0.00% 0.38% -0.01% -1.90% -0.06%  0.09%
# Avg returns winning              nan% 0.38%   nan%   nan%   nan%  0.59%
# Avg returns losing             -0.00%  nan% -0.01% -1.90% -0.06% -0.16%
# Median returns all round_trips -0.00% 0.30% -0.01% -1.90% -0.06% -0.00%
# Median returns winning           nan% 0.30%   nan%   nan%   nan%  0.59%
# Median returns losing          -0.00%  nan% -0.01% -1.90% -0.06% -0.16%
# Largest winning trade          -0.00% 0.83% -0.01% -0.02% -0.03%  0.59%
# Largest losing trade           -0.00% 0.12% -0.01% -3.78% -0.10% -0.32%
#
# Symbol stats                      LPX   LSEA  LVGO    MBT  MGNX   MGY    MIK  \
# Avg returns all round_trips    -0.31% -0.01% 0.54% -1.18% 2.09% 0.40% -0.34%
# Avg returns winning             0.25%   nan% 0.54%   nan% 2.09% 0.40%  0.02%
# Avg returns losing             -1.72% -0.01%  nan% -1.18%  nan%  nan% -1.40%
# Median returns all round_trips  0.07% -0.01% 0.50% -1.18% 2.09% 0.40%  0.00%
# Median returns winning          0.10%   nan% 0.50%   nan% 2.09% 0.40%  0.00%
# Median returns losing          -0.14% -0.01%  nan% -1.18%  nan%  nan% -1.40%
# Largest winning trade           0.93% -0.01% 1.65% -1.18% 2.09% 0.40%  0.05%
# Largest losing trade           -6.58% -0.01% 0.12% -1.18% 2.09% 0.40% -1.40%
#
# Symbol stats                       MU   MYOV    NIU    NTR    NVO    OAK  \
# Avg returns all round_trips     0.12% -0.92% -0.03%  0.18%  0.07% -0.19%
# Avg returns winning             0.28%   nan%  0.72%  0.60%  0.40%   nan%
# Avg returns losing             -0.40% -0.92% -1.04% -0.24% -0.21% -0.19%
# Median returns all round_trips  0.03% -0.92%  0.05%  0.18% -0.00% -0.10%
# Median returns winning          0.09%   nan%  0.59%  0.60%  0.42%   nan%
# Median returns losing          -0.01% -0.92% -0.94% -0.24% -0.06% -0.10%
# Largest winning trade           1.77% -0.92%  1.65%  0.60%  0.67% -0.03%
# Largest losing trade           -2.73% -0.92% -1.37% -0.24% -0.61% -0.44%
#
# Symbol stats                     OCUL   OMI   ORCL  PAYC   PCAR   PDM   PFNX  \
# Avg returns all round_trips    -0.06% 0.61%  0.15% 0.45%  0.06% 0.41% -0.04%
# Avg returns winning             0.34% 0.61%  0.24% 0.45%  0.23% 0.41%   nan%
# Avg returns losing             -0.32%  nan% -0.13%  nan% -0.14%  nan% -0.04%
# Median returns all round_trips -0.14% 0.61%  0.01% 0.48%  0.00% 0.41% -0.04%
# Median returns winning          0.34% 0.61%  0.04% 0.48%  0.08% 0.41%   nan%
# Median returns losing          -0.17%  nan% -0.09%  nan% -0.17%  nan% -0.04%
# Largest winning trade           0.59% 0.61%  1.30% 0.68%  1.06% 0.41% -0.02%
# Largest losing trade           -0.65% 0.61% -0.42% 0.19% -0.30% 0.41% -0.04%
#
# Symbol stats                      PLL   PLNT   PPBT
# Avg returns all round_trips     0.24% -0.16% -0.91%
# Avg returns winning             0.78%  0.29%   nan%
# Avg returns losing             -0.29% -0.60% -0.91%
# Median returns all round_trips  0.03%  0.02% -0.91%
# Median returns winning          0.78%  0.22%   nan%
# Median returns losing          -0.29% -0.51% -0.91%
# Largest winning trade           1.38%  0.75% -0.91%
# Largest losing trade           -0.47% -1.21% -0.91%
# Profitability (PnL / PnL total) per name
# symbol
# IMMU                                     19.41%
# CVNA                                     16.47%
# FUTU                                     11.46%
# MU                                       11.19%
# CPRI                                      9.49%
# LVGO                                      9.18%
# DFS                                       7.69%
# IPOE                                      6.31%
# GRUB                                      6.24%
# JEF                                       5.43%
# FOLD                                      5.10%
# ORCL                                      4.61%
# FIS                                       3.89%
# CRSP                                      3.61%
# EQNR                                      3.09%
# MGNX                                      2.99%
# ATVI                                      2.92%
# ATHM                                      2.41%
# CPSH                                      2.22%
# BLDP                                      2.21%
# AA                                        2.04%
# LCI                                       1.85%
# PAYC                                      1.81%
# PLL                                       1.80%
# ENVA                                      1.79%
# AVID                                      1.66%
# GHVI                                      1.48%
# ALL                                       1.44%
# NVO                                       1.28%
# INFY                                      1.27%
# GRFS                                      1.23%
# OMI                                       1.03%
# PCAR                                      0.98%
# NTR                                       0.92%
# PDM                                       0.83%
# A                                         0.80%
# FND                                       0.68%
# JIH                                       0.57%
# MGY                                       0.57%
# HFC                                       0.54%
# HDS                                       0.53%
# LOW                                       0.37%
# AME                                       0.34%
# GPC                                       0.24%
# ADI                                       0.24%
# KMX                                       0.21%
# GTXMQ                                     0.12%
# GD                                        0.10%
# AVLR                                      0.06%
# CSTE                                      0.02%
# BRSS                                     -0.00%
# KOPN                                     -0.01%
# LSEA                                     -0.01%
# LH                                       -0.02%
# BURL                                     -0.11%
# BITA                                     -0.12%
# LOGM                                     -0.15%
# PFNX                                     -0.18%
# AMED                                     -0.21%
# IDYA                                     -0.22%
# BXP                                      -0.23%
# FNB                                      -0.26%
# COHR                                     -0.30%
# AZEK                                     -0.44%
# OCUL                                     -0.46%
# NIU                                      -0.52%
# ALKS                                     -0.57%
# DKS                                      -0.65%
# AY                                       -0.66%
# OAK                                      -0.68%
# HD                                       -0.70%
# GRMN                                     -0.72%
# GFI                                      -0.74%
# HEC                                      -0.75%
# CWEN                                     -0.76%
# GILD                                     -0.88%
# HUN                                      -1.07%
# MBT                                      -1.51%
# PPBT                                     -1.60%
# MIK                                      -1.61%
# ALGN                                     -1.66%
# CDEV                                     -1.67%
# MYOV                                     -1.99%
# BMRN                                     -2.13%
# PLNT                                     -2.72%
# CF                                       -3.32%
# FE                                       -3.81%
# CME                                      -4.00%
# LPX                                      -4.01%
# APPN                                     -5.13%
# BLNK                                     -7.68%
# LIZI                                     -8.49%
