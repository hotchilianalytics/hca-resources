# %%
# %%html
# <style>
#   table {margin-left: 0 !important;}
# </style>
# Out:
# <style>
#   table {margin-left: 0 !important;}
# </style>

# %% [markdown]
# <img src="http://drive.google.com/uc?export=view&id=1zJjN-vEjutF__7wpEq5Yibxv9BRZeC74"
#      alt="HCA Logo" height="150" width="150"
#      style="float: left; margin-right: 10px;">
#
# |Name  | Value |
# | :- |:-------------: |
# | **Notebook:**  | **HotChili Trader Tear Sheet** |
# | **Version:**  | 1.0.1c |
# | **Date:**  | 2020-08-06  |
# | **Copyright:**  | @2019-2020 |
# | **Company:**  | **HotChili Analytics, LLC** |
# | **Author   :**  | Alan Coppola|(ajjcoppola@hotchilianalytics.com) |
# | **Author   :**  | Jeff Coppola|(jeff@hotchilianalytics.com) |

# %%
import pandas as pd
import numpy as np
import matplotlib as mp
import matplotlib.pyplot as plt
import pyfolio as pf
# %matplotlib inline

# silence warnings
import warnings
warnings.filterwarnings('ignore')
### %pylab inline
###figsize(12, 12)
# Out:
# WARNING (theano.configdefaults): install mkl with `conda install mkl-service`: No module named 'mkl'
# /home/hca-r2-001/miniconda3/envs/hca/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %%
pd.set_option("max_colwidth", 400)
pd.set_option("display.max_rows", 100000)
pd.set_option("display.max_columns", 1000)
pd.set_option('precision', 2)
pd.options.display.float_format = '{:20,.2f}'.format

# %%
# Parameters for location of zipline-broker run
#hca/hca-resources/HCA_Fundamentals/fund_bt.pkl
#hca/hca-resources/HCA_Fundamentals/fund_bt.pkl
nb_dir = "/home/hca-ws2003/hca/hca-resources/HCA_Fundamentals/"
ans_pkl = "HCA_Fundamentals.pkl"
ans_data_file = nb_dir + ans_pkl

# Read in backtest results for analysis
perf=pd.read_pickle(ans_data_file)

# %%
perf.columns
#dir(perf)
# Out:
# Index(['algo_volatility', 'algorithm_period_return', 'alpha',
#        'benchmark_period_return', 'benchmark_volatility', 'beta',
#        'capital_used', 'ending_cash', 'ending_exposure', 'ending_value',
#        'excess_return', 'gross_leverage', 'leverage', 'long_count',
#        'long_exposure', 'long_value', 'longs_count', 'max_drawdown',
#        'max_leverage', 'net_leverage', 'orders', 'period_close',
#        'period_label', 'period_open', 'pnl', 'port_wts', 'portfolio_value',
#        'positions', 'returns', 'sharpe', 'short_count', 'short_exposure',
#        'short_value', 'shorts_count', 'sortino', 'starting_cash',
#        'starting_exposure', 'starting_value', 'trading_days', 'transactions',
#        'treasury_period_return'],
#       dtype='object')

# %%
perf.shape
# Out:
# (509, 41)

# %%
import pandas as pd
returns, positions, transactions= pf.utils.extract_rets_pos_txn_from_zipline(perf)

# %%
#positions

# %%
#transactions

# %%
import sys

print("Tear Sheet File : {}".format(ans_data_file))
print("-----------------------------------")
print("Python version={}".format(sys.version))
print("Matplotlib version={}".format(mp.__version__))
print("Numpy version={}".format(np.version.version))
# Out:
# Tear Sheet File : /home/hca-ws2003/hca/hca-resources/HCA_Fundamentals/HCA_Fundamentals.pkl
# -----------------------------------
# Python version=3.6.7 |Anaconda, Inc.| (default, Oct 23 2018, 19:16:44)
# [GCC 7.3.0]
# Matplotlib version=3.1.1
# Numpy version=1.14.0

# %%
#pf.plot_drawdown_periods(returns, top=5).set_xlabel('Date')

# %%
#returns.plot()

# %%
#transactions

# %%
#from datetime import datetime
#import pytz
#start = datetime(2017, 2, 11, 0, 0, 0, 0, pytz.utc)
#end = datetime(2019, 3, 14, 0, 0, 0, 0, pytz.utc)
#s=pd.Timestamp(start)

# %%
#pf.create_position_tear_sheet(returns=returns,positions=positions)
#pf.plot_perf_stats(returns= returns, factor_returns=returns)

# %%
sim_start=perf.index[0]
sim_end= perf.index[-1]
print("start={}  end={}".format(sim_start,sim_end))
# Out:
# start=2019-04-01 00:00:00+00:00  end=2021-04-07 00:00:00+00:00

# %%
#%%pixie_debugger

from zipline.data import benchmarks
# Set up benchmark Asset 
spy_bm_ret    = benchmarks.get_benchmark_returns(symbol='SPY', first_date=sim_start, last_date=sim_end)
spy_bm_ret    = spy_bm_ret[sim_start:sim_end]
spy_bm_ret[0] = 0.0 # Normalize benchmark returns to start at 0.0.
perf          = perf[sim_start:sim_end]

returns, positions, transactions = pf.utils.extract_rets_pos_txn_from_zipline(perf)
#pf.create_txn_tear_sheet(returns, positions=positions, transactions=transactions)
#pf.create_round_trip_tear_sheet(returns, positions=positions, transactions=transactions)
pf.create_full_tear_sheet(returns, positions=positions, transactions=transactions, bootstrap=None,benchmark_rets=spy_bm_ret, round_trips=True)
#pf.create_simple_tear_sheet(returns=returns,positions=positions,transactions=transactions,benchmark_rets=spy_bm_ret)
# Out:
# Entire data start date: 2019-04-02
# Entire data end date: 2021-04-07
# Backtest months: 24
#                     Backtest
# Annual return          31.3%
# Cumulative returns     73.2%
# Annual volatility      32.6%
# Sharpe ratio            1.00
# Calmar ratio            0.79
# Stability               0.75
# Max drawdown          -39.7%
# Omega ratio             1.21
# Sortino ratio           1.41
# Skew                   -0.68
# Kurtosis               10.20
# Tail ratio              0.96
# Daily value at risk    -4.0%
# Gross leverage          0.89
# Daily turnover          7.6%
# Alpha                   0.11
# Beta                    1.05
# Worst drawdown periods Net drawdown in %  Peak date Valley date Recovery date  \
# 0                                  39.69 2020-02-19  2020-03-23    2020-06-03
# 1                                  13.13 2020-06-08  2020-06-26    2020-08-28
# 2                                  11.46 2019-04-08  2019-10-08    2019-11-04
# 3                                   8.80 2021-02-19  2021-04-07           NaT
# 4                                   8.60 2020-10-12  2020-10-28    2020-11-16
#
# Worst drawdown periods Duration
# 0                            76
# 1                            60
# 2                           151
# 3                           NaN
# 4                            26
# Stress Events  mean     min    max
# New Normal    0.13% -15.16% 10.84%
# Top 10 long positions of all time    max
# EAT                               30.75%
# MRVL                              29.66%
# GSX                               28.55%
# IIVI                              25.35%
# CRWD                              25.11%
# EIX                               24.27%
# NVDA                              22.93%
# EDU                               22.67%
# LNT                               22.51%
# CUBE                              22.42%
# Empty DataFrame
# Columns: [max]
# Index: []
# Top 10 positions of all time    max
# EAT                          30.75%
# MRVL                         29.66%
# GSX                          28.55%
# IIVI                         25.35%
# CRWD                         25.11%
# EIX                          24.27%
# NVDA                         22.93%
# EDU                          22.67%
# LNT                          22.51%
# CUBE                         22.42%
# All positions ever held    max
# EAT                     30.75%
# MRVL                    29.66%
# GSX                     28.55%
# IIVI                    25.35%
# CRWD                    25.11%
# EIX                     24.27%
# NVDA                    22.93%
# EDU                     22.67%
# LNT                     22.51%
# CUBE                    22.42%
# PLD                     21.02%
# EPR                     20.88%
# LRCX                    20.86%
# NCLH                    20.63%
# LYB                     19.73%
# HE                      16.82%
# M                       16.54%
# MAT                     16.53%
# MOS                     15.97%
# CGNX                    14.85%
# A                       14.19%
# ADI                     14.15%
# CVS                     14.03%
# BAM                     13.92%
# JCI                     13.86%
# BHC                     13.71%
# ALL                     13.29%
# PDM                     13.29%
# COST                    12.99%
# CVM                     12.07%
# BPY                     12.03%
# NUS                     11.76%
# IQV                     11.55%
# ERJ                     11.54%
# PNC                     11.38%
# ATUS                    11.31%
# CINF                    11.24%
# OII                     11.22%
# ALGN                    11.21%
# ASAZY                   11.20%
# GRUB                    11.09%
# ON                      11.07%
# CMC                     11.02%
# AME                     10.99%
# LEG                     10.98%
# MGY                     10.89%
# CLF                     10.89%
# CLDX                    10.86%
# HNGR                    10.77%
# MTCH2                   10.66%
# J                       10.56%
# FLO                     10.34%
# GP                      10.26%
# AA                      10.01%
# BURL                     9.97%
# PLUG                     9.92%
# CMCSA                    9.85%
# OI                       9.76%
# FG                       9.68%
# BDN                      9.42%
# FTSV                     9.42%
# DKNG                     9.26%
# ATHM                     9.23%
# BXP                      9.18%
# CCIV                     8.74%
# APPN                     8.72%
# KPTI                     8.71%
# ALKS                     8.65%
# FUTU                     8.61%
# FUBO                     8.48%
# CLR                      8.48%
# CF                       8.38%
# AXS                      8.24%
# ATHA                     7.97%
# BMRA                     7.75%
# NVMI                     7.56%
# GHVI                     7.13%
# CRON                     7.06%
# MSTR                     6.94%
# ESPR                     6.22%
# FRTA                     6.19%
# ORMP                     6.02%
# BRPA                     5.89%
# INSG                     5.76%
# CDE                      5.74%
# CMMB                     5.64%
# HPR                      4.62%
# Summary stats                All trades  Long trades
# Total number of round_trips      813.00       813.00
# Percent profitable                 0.66         0.66
# Winning round_trips              537.00       537.00
# Losing round_trips               276.00       276.00
# Even round_trips                   0.00         0.00
# PnL stats                   All trades   Long trades
# Total profit               $7352959.54   $7352959.54
# Gross profit              $21316805.11  $21316805.11
# Gross loss               $-13963845.57 $-13963845.57
# Profit factor                    $1.53         $1.53
# Avg. trade net profit         $9044.23      $9044.23
# Avg. winning trade           $39696.10     $39696.10
# Avg. losing trade           $-50593.64    $-50593.64
# Ratio Avg. Win:Avg. Loss         $0.78         $0.78
# Largest winning trade       $782667.98    $782667.98
# Largest losing trade       $-595287.02   $-595287.02
# Duration stats                 All trades             Long trades
# Avg duration      21 days 08:22:48.277982 21 days 08:22:48.277982
# Median duration          14 days 00:00:00        14 days 00:00:00
# Longest duration        123 days 01:00:00       123 days 01:00:00
# Shortest duration         3 days 00:00:00         3 days 00:00:00
# Return stats                    All trades  Long trades
# Avg returns all round_trips          0.06%        0.06%
# Avg returns winning                  0.32%        0.32%
# Avg returns losing                  -0.46%       -0.46%
# Median returns all round_trips       0.02%        0.02%
# Median returns winning               0.09%        0.09%
# Median returns losing               -0.20%       -0.20%
# Largest winning trade                6.23%        6.23%
# Largest losing trade                -6.01%       -6.01%
# Symbol stats                        A     AA    ADI   ALGN   ALKS    ALL  \
# Avg returns all round_trips    -0.04%  0.08% -0.08% -1.10% -0.01%  0.35%
# Avg returns winning             0.13%  0.29%  0.11%   nan%  0.14%  0.44%
# Avg returns losing             -0.53% -0.34% -0.35% -1.10% -0.44% -0.18%
# Median returns all round_trips  0.02%  0.06%  0.00% -1.10%  0.00%  0.03%
# Median returns winning          0.03%  0.27%  0.03%   nan%  0.00%  0.17%
# Median returns losing          -0.20% -0.34% -0.13% -1.10% -0.44% -0.18%
# Largest winning trade           0.69%  0.60%  0.79% -0.67%  0.41%  1.95%
# Largest losing trade           -1.55% -0.59% -1.75% -1.54% -0.44% -0.18%
#
# Symbol stats                      AME   APPN  ASAZY  ATHA   ATHM   ATUS  \
# Avg returns all round_trips     0.13% -0.73%  0.04% 0.57%  0.14%  0.08%
# Avg returns winning             0.49%   nan%  0.05% 0.57%  0.99%  0.15%
# Avg returns losing             -0.22% -0.73% -0.01%  nan% -0.72% -0.05%
# Median returns all round_trips  0.13% -0.74%  0.04% 0.57%  0.14%  0.00%
# Median returns winning          0.49%   nan%  0.06% 0.57%  0.99%  0.01%
# Median returns losing          -0.22% -0.74% -0.00%  nan% -0.72% -0.04%
# Largest winning trade           0.49% -0.13%  0.11% 0.79%  0.99%  1.09%
# Largest losing trade           -0.22% -1.29% -0.01% 0.35% -0.72% -0.11%
#
# Symbol stats                      AXS    BAM    BDN    BHC   BMRA    BPY  \
# Avg returns all round_trips    -0.19%  0.09%  0.07%  0.06% -0.14% -0.32%
# Avg returns winning              nan%  0.15%  0.15%  0.22%   nan%  0.15%
# Avg returns losing             -0.19% -0.06% -0.01% -0.28% -0.14% -0.94%
# Median returns all round_trips -0.19%  0.02%  0.07%  0.01% -0.14%  0.02%
# Median returns winning           nan%  0.04%  0.15%  0.03%   nan%  0.09%
# Median returns losing          -0.19% -0.05% -0.01% -0.17% -0.14% -0.02%
# Largest winning trade          -0.19%  1.40%  0.15%  1.56% -0.14%  0.36%
# Largest losing trade           -0.19% -0.16% -0.01% -0.78% -0.14% -5.35%
#
# Symbol stats                     BRPA   BURL    BXP  CCIV    CDE     CF  \
# Avg returns all round_trips    -0.13% -0.09% -0.05% 0.70% -0.45% -0.05%
# Avg returns winning              nan%   nan%  0.35% 0.70%   nan%  1.11%
# Avg returns losing             -0.13% -0.09% -0.44%  nan% -0.45% -0.44%
# Median returns all round_trips -0.11% -0.09% -0.17% 0.41% -0.45% -0.21%
# Median returns winning           nan%   nan%  0.08% 0.41%   nan%  1.11%
# Median returns losing          -0.11% -0.09% -0.40%  nan% -0.45% -0.40%
# Largest winning trade          -0.08% -0.09%  0.91% 2.19% -0.45%  1.11%
# Largest losing trade           -0.22% -0.09% -0.55% 0.00% -0.45% -0.89%
#
# Symbol stats                     CGNX  CINF   CLDX    CLF    CLR   CMC  CMCSA  \
# Avg returns all round_trips    -0.41% 0.38% -0.43%  0.01%  0.31% 0.16%  0.16%
# Avg returns winning              nan% 0.38%   nan%  0.30%  0.66% 0.16%  0.16%
# Avg returns losing             -0.41%  nan% -0.43% -0.66% -0.04%  nan%   nan%
# Median returns all round_trips -0.09% 0.37% -0.38%  0.07%  0.31% 0.01%  0.12%
# Median returns winning           nan% 0.37%   nan%  0.20%  0.66% 0.01%  0.12%
# Median returns losing          -0.09%  nan% -0.38% -0.37% -0.04%  nan%   nan%
# Largest winning trade          -0.02% 0.40% -0.21%  1.17%  0.66% 0.46%  0.39%
# Largest losing trade           -1.13% 0.37% -0.72% -1.90% -0.04% 0.00%  0.02%
#
# Symbol stats                     CMMB   COST   CRON   CRWD   CUBE    CVM  \
# Avg returns all round_trips    -0.12%  0.19% -0.06%  0.35% -0.26% -0.20%
# Avg returns winning             0.08%  0.30%  0.05%  0.53%  0.09%  0.39%
# Avg returns losing             -0.33% -0.06% -0.16% -0.66% -0.34% -0.49%
# Median returns all round_trips -0.12%  0.02% -0.00%  0.12% -0.16% -0.21%
# Median returns winning          0.08%  0.04%  0.05%  0.17%  0.09%  0.39%
# Median returns losing          -0.33% -0.05% -0.16% -0.81% -0.28% -0.51%
# Largest winning trade           0.08%  1.27%  0.09%  2.56%  0.10%  0.64%
# Largest losing trade           -0.33% -0.14% -0.31% -1.00% -0.96% -0.92%
#
# Symbol stats                      CVS   DKNG    EAT    EDU    EIX    EPR  \
# Avg returns all round_trips     0.27%  0.19%  0.88% -0.05% -0.11%  2.64%
# Avg returns winning             0.30%  0.28%  1.07%  0.12%  0.23%  3.97%
# Avg returns losing             -0.00% -0.11% -0.34% -0.25% -0.39% -0.03%
# Median returns all round_trips  0.02%  0.11%  0.49%  0.01% -0.00%  1.71%
# Median returns winning          0.03%  0.14%  0.55%  0.04%  0.19%  3.97%
# Median returns losing          -0.00% -0.06% -0.34% -0.10% -0.21% -0.03%
# Largest winning trade           1.64%  0.91%  4.47%  1.10%  0.51%  6.23%
# Largest losing trade           -0.00% -0.22% -0.53% -1.25% -1.12% -0.03%
#
# Symbol stats                      ERJ  ESPR     FG    FLO  FRTA  FTSV  FUBO  \
# Avg returns all round_trips    -2.64% 0.46% -0.55% -0.23% 0.02% 1.28% 0.79%
# Avg returns winning              nan% 0.46%   nan%   nan% 0.02% 1.28% 0.79%
# Avg returns losing             -2.64%  nan% -0.55% -0.23%  nan%  nan%  nan%
# Median returns all round_trips -2.64% 0.46% -0.55% -0.23% 0.02% 1.28% 0.79%
# Median returns winning           nan% 0.46%   nan%   nan% 0.02% 1.28% 0.79%
# Median returns losing          -2.64%  nan% -0.55% -0.23%  nan%  nan%  nan%
# Largest winning trade          -0.85% 0.46% -0.55% -0.23% 0.05% 1.28% 0.79%
# Largest losing trade           -4.43% 0.46% -0.55% -0.23% 0.00% 1.28% 0.79%
#
# Symbol stats                     FUTU   GHVI     GP   GRUB    GSX     HE  \
# Avg returns all round_trips    -0.42%  0.13%  0.01%  0.28% -0.06% -0.37%
# Avg returns winning              nan%  0.23%  0.38%  0.64%  0.46%   nan%
# Avg returns losing             -0.42% -0.07% -0.73% -0.42% -2.38% -0.37%
# Median returns all round_trips -0.42%  0.02%  0.34%  0.12%  0.32% -0.37%
# Median returns winning           nan%  0.23%  0.38%  0.46%  0.39%   nan%
# Median returns losing          -0.42% -0.07% -0.73% -0.42% -1.88% -0.37%
# Largest winning trade          -0.01%  0.44%  0.42%  1.59%  1.72% -0.24%
# Largest losing trade           -0.83% -0.07% -0.73% -0.61% -6.01% -0.49%
#
# Symbol stats                    HNGR    HPR   IIVI   INSG    IQV      J  \
# Avg returns all round_trips    0.17% -0.91%  0.22% -0.95% -0.40% -0.28%
# Avg returns winning            0.17%   nan%  0.59%   nan%  0.13%   nan%
# Avg returns losing              nan% -0.91% -1.05% -0.95% -1.12% -0.28%
# Median returns all round_trips 0.17% -0.91%  0.26% -0.95%  0.02% -0.28%
# Median returns winning         0.17%   nan%  0.35%   nan%  0.12%   nan%
# Median returns losing           nan% -0.91% -1.05% -0.95% -0.26% -0.28%
# Largest winning trade          0.32% -0.91%  2.41% -0.95%  0.26% -0.28%
# Largest losing trade           0.02% -0.91% -1.48% -0.95% -3.05% -0.28%
#
# Symbol stats                      JCI   KPTI    LEG    LNT   LRCX    LYB  \
# Avg returns all round_trips     0.07% -0.24% -1.28% -0.03%  0.21%  0.06%
# Avg returns winning             0.15%   nan%   nan%  0.40%  0.60%  0.34%
# Avg returns losing             -0.07% -0.24% -1.28% -0.47% -0.31% -0.51%
# Median returns all round_trips  0.01% -0.24% -1.28% -0.05%  0.08%  0.01%
# Median returns winning          0.11%   nan%   nan%  0.21%  0.40%  0.04%
# Median returns losing          -0.00% -0.24% -1.28% -0.15% -0.24% -0.58%
# Largest winning trade           0.44% -0.24% -1.28%  1.74%  2.12%  2.32%
# Largest losing trade           -0.28% -0.24% -1.28% -2.26% -0.90% -1.01%
#
# Symbol stats                        M    MAT    MGY    MOS   MRVL   MSTR  \
# Avg returns all round_trips    -0.09% -0.03%  0.20% -0.16%  0.35% -0.64%
# Avg returns winning             0.22%  0.18%  0.48%  0.19%  0.38%  0.50%
# Avg returns losing             -0.55% -0.61% -0.17% -0.65% -0.16% -1.78%
# Median returns all round_trips  0.01%  0.02%  0.04%  0.01%  0.02% -0.64%
# Median returns winning          0.03%  0.06%  0.35%  0.05%  0.03%  0.50%
# Median returns losing          -0.62% -0.13% -0.11% -0.66% -0.16% -1.78%
# Largest winning trade           1.06%  1.94%  1.16%  1.37%  2.69%  0.50%
# Largest losing trade           -0.95% -2.89% -0.39% -1.67% -0.16% -1.78%
#
# Symbol stats                    MTCH2   NCLH    NUS   NVDA   NVMI     OI  \
# Avg returns all round_trips     0.47%  0.13% -0.34%  0.14%  0.01% -0.19%
# Avg returns winning             0.47%  0.41%  0.11%  0.29%  0.05%  0.31%
# Avg returns losing               nan% -0.33% -0.80% -0.35% -0.03% -0.95%
# Median returns all round_trips  0.47%  0.02% -0.34%  0.11%  0.01%  0.04%
# Median returns winning          0.47%  0.11%  0.11%  0.18%  0.05%  0.41%
# Median returns losing            nan% -0.17% -0.80% -0.22% -0.03% -0.95%
# Largest winning trade           0.47%  5.37%  0.11%  1.91%  0.05%  0.49%
# Largest losing trade            0.47% -1.36% -0.80% -1.25% -0.03% -1.34%
#
# Symbol stats                      OII     ON  ORMP    PDM    PLD   PLUG    PNC
# Avg returns all round_trips    -0.14% -0.07% 0.27% -1.25%  0.05%  0.39%  0.06%
# Avg returns winning             0.58%  0.13% 0.27%   nan%  0.16%  0.43%  0.19%
# Avg returns losing             -0.49% -0.43%  nan% -1.25% -0.30% -0.22% -0.36%
# Median returns all round_trips -0.33%  0.00% 0.27% -1.25%  0.01%  0.25%  0.04%
# Median returns winning          0.58%  0.01% 0.27%   nan%  0.04%  0.29%  0.10%
# Median returns losing          -0.41% -0.05%  nan% -1.25% -0.08% -0.22% -0.40%
# Largest winning trade           0.65%  0.60% 0.49% -1.25%  1.53%  1.38%  0.68%
# Largest losing trade           -0.90% -1.62% 0.04% -1.25% -1.21% -0.22% -0.83%
# Profitability (PnL / PnL total) per name
# symbol
# EAT                                      20.48%
# CCIV                                     15.19%
# PLUG                                     13.68%
# CRWD                                     13.56%
# EPR                                      12.81%
# MRVL                                     10.21%
# NCLH                                      8.41%
# LRCX                                      6.08%
# NVDA                                      5.95%
# COST                                      5.38%
# DKNG                                      4.77%
# ALL                                       3.29%
# CVS                                       3.25%
# BAM                                       2.84%
# ATUS                                      2.79%
# MGY                                       2.62%
# LYB                                       2.41%
# CLF                                       2.39%
# IIVI                                      2.30%
# PNC                                       2.27%
# GRUB                                      2.25%
# ATHA                                      2.23%
# PLD                                       1.92%
# FTSV                                      1.82%
# CINF                                      1.75%
# MAT                                       1.69%
# JCI                                       1.62%
# FUBO                                      1.52%
# ATHM                                      1.30%
# ORMP                                      1.29%
# AA                                        1.27%
# CLR                                       1.25%
# ASAZY                                     1.22%
# ESPR                                      1.09%
# CMCSA                                     1.08%
# GHVI                                      1.01%
# BHC                                       0.89%
# MTCH2                                     0.64%
# CMC                                       0.62%
# GSX                                       0.53%
# HNGR                                      0.45%
# AME                                       0.33%
# BDN                                       0.22%
# CF                                        0.17%
# FRTA                                      0.12%
# GP                                        0.10%
# NVMI                                      0.03%
# BURL                                     -0.12%
# LNT                                      -0.12%
# ALKS                                     -0.13%
# BXP                                      -0.15%
# BMRA                                     -0.17%
# M                                        -0.18%
# FLO                                      -0.31%
# OII                                      -0.31%
# AXS                                      -0.34%
# J                                        -0.35%
# KPTI                                     -0.41%
# CRON                                     -0.55%
# CMMB                                     -0.64%
# A                                        -0.79%
# FG                                       -0.80%
# HE                                       -0.82%
# NUS                                      -0.92%
# ON                                       -0.96%
# CDE                                      -1.08%
# OI                                       -1.14%
# CGNX                                     -1.32%
# EIX                                      -1.36%
# PDM                                      -1.44%
# FUTU                                     -1.53%
# LEG                                      -1.63%
# EDU                                      -1.69%
# BRPA                                     -1.94%
# HPR                                      -2.14%
# INSG                                     -2.29%
# CLDX                                     -2.42%
# CVM                                      -2.48%
# ALGN                                     -2.77%
# IQV                                      -3.01%
# MSTR                                     -3.12%
# CUBE                                     -3.19%
# ADI                                      -3.31%
# BPY                                      -3.90%
# APPN                                     -5.30%
# ERJ                                      -6.78%
# MOS                                      -7.19%
