# %%
# %%html
# <style>
#   table {margin-left: 0 !important;}
# </style>
# Out:
# <style>
#   table {margin-left: 0 !important;}
# </style>

# %% [markdown]
# <img src="http://drive.google.com/uc?export=view&id=1zJjN-vEjutF__7wpEq5Yibxv9BRZeC74"
#      alt="HCA Logo" height="150" width="150"
#      style="float: left; margin-right: 10px;">
#
# |Name  | Value |
# | :- |:-------------: |
# | **Notebook:**  | **HotChili Trader Tear Sheet** |
# | **Version:**  | 1.0.1c |
# | **Date:**  | 2020-08-06  |
# | **Copyright:**  | @2019-2020 |
# | **Company:**  | **HotChili Analytics, LLC** |
# | **Author   :**  | Alan Coppola|(ajjcoppola@hotchilianalytics.com) |
# | **Author   :**  | Jeff Coppola|(jeff@hotchilianalytics.com) |

# %%
import pandas as pd
import numpy as np
import matplotlib as mp
import matplotlib.pyplot as plt
import pyfolio as pf
# %matplotlib inline

# silence warnings
import warnings
warnings.filterwarnings('ignore')
### %pylab inline
###figsize(12, 12)
# Out:
# WARNING (theano.configdefaults): install mkl with `conda install mkl-service`: No module named 'mkl'
# /home/hca-r2-001/miniconda3/envs/hca/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %%
import os

hca_root_path = os.environ['HCA_ROOT']
print(f"hca_root_path = {hca_root_path}")

# Parameters for location of zipline-broker run
nb_dir        = hca_root_path + "/hca-resources/HCA_Fixed_Ratio_Allocations/" 

# Parameters for location of zipline-broker run
ans_pkl       = "HCA_Fixed_Ratio_Allocations.pkl"
ans_data_file = nb_dir + ans_pkl

# Read in backtest results for analysis
perf=pd.read_pickle(ans_data_file)
# Out:
# hca_root_path = /home/hca-ws2004/hca

# %%
import pandas as pd
returns, positions, transactions= pf.utils.extract_rets_pos_txn_from_zipline(perf)

# %%
#transactions

# %%
import sys

print("Tear Sheet File : {}".format(ans_data_file))
print("-----------------------------------")
print("Python version={}".format(sys.version))
print("Matplotlib version={}".format(mp.__version__))
print("Numpy version={}".format(np.version.version))
# Out:
# Tear Sheet File : /home/hca-ws2004/hca/hca-resources/HCA_Fixed_Ratio_Allocations/HCA_Fixed_Ratio_Allocations.pkl
# -----------------------------------
# Python version=3.6.7 |Anaconda, Inc.| (default, Oct 23 2018, 19:16:44)
# [GCC 7.3.0]
# Matplotlib version=3.1.1
# Numpy version=1.14.0

# %%
#pf.plot_drawdown_periods(returns, top=5).set_xlabel('Date')

# %%
#returns.plot()

# %%
#transactions

# %%
#from datetime import datetime
#import pytz
#start = datetime(2017, 2, 11, 0, 0, 0, 0, pytz.utc)
#end = datetime(2019, 3, 14, 0, 0, 0, 0, pytz.utc)
#s=pd.Timestamp(start)

# %%
#pf.create_position_tear_sheet(returns=returns,positions=positions)
#pf.plot_perf_stats(returns= returns, factor_returns=returns)

# %%
sim_start=perf.index[0]
sim_end= perf.index[-1]
print("start={}  end={}".format(sim_start,sim_end))
# Out:
# start=2018-01-02 00:00:00+00:00  end=2021-04-09 00:00:00+00:00

# %%
#%%pixie_debugger

from zipline.data import benchmarks
# Set up benchmark Asset 
spy_bm_ret    = benchmarks.get_benchmark_returns(symbol='SPY', first_date=sim_start, last_date=sim_end)
spy_bm_ret    = spy_bm_ret[sim_start:sim_end]
spy_bm_ret[0] = 0.0 # Normalize benchmark returns to start at 0.0.
perf          = perf[sim_start:sim_end]

returns, positions, transactions = pf.utils.extract_rets_pos_txn_from_zipline(perf)

pf.create_full_tear_sheet(returns, positions=positions, transactions=transactions, bootstrap=None,benchmark_rets=spy_bm_ret, round_trips=True)
#pf.create_simple_tear_sheet(returns=returns,positions=positions,transactions=transactions)
# Out:
# Entire data start date: 2018-01-03
# Entire data end date: 2021-04-09
# Backtest months: 39
#                     Backtest
# Annual return           9.0%
# Cumulative returns     32.5%
# Annual volatility       7.3%
# Sharpe ratio            1.22
# Calmar ratio            0.80
# Stability               0.91
# Max drawdown          -11.2%
# Omega ratio             1.25
# Sortino ratio           1.71
# Skew                   -0.83
# Kurtosis                8.88
# Tail ratio              0.94
# Daily value at risk    -0.9%
# Gross leverage          1.01
# Daily turnover          0.1%
# Alpha                   0.06
# Beta                    0.17
# Worst drawdown periods Net drawdown in %  Peak date Valley date Recovery date  \
# 0                                  11.24 2020-03-06  2020-03-18    2020-04-14
# 1                                   6.28 2020-08-06  2021-03-04           NaT
# 2                                   4.63 2018-01-26  2018-10-29    2019-01-31
# 3                                   2.77 2019-09-04  2019-09-13    2019-12-26
# 4                                   2.66 2020-02-21  2020-02-28    2020-03-05
#
# Worst drawdown periods Duration
# 0                            28
# 1                           NaN
# 2                           265
# 3                            82
# 4                            10
# Stress Events  mean    min   max
# New Normal    0.04% -3.26% 2.47%
# Top 10 long positions of all time    max
# SPY                               30.53%
# TLT                               30.25%
# GLD                               28.32%
# SHY                               26.62%
# Empty DataFrame
# Columns: [max]
# Index: []
# Top 10 positions of all time    max
# SPY                          30.53%
# TLT                          30.25%
# GLD                          28.32%
# SHY                          26.62%
# All positions ever held    max
# SPY                     30.53%
# TLT                     30.25%
# GLD                     28.32%
# SHY                     26.62%
# Summary stats                All trades  Long trades
# Total number of round_trips       12.00        12.00
# Percent profitable                 1.00         1.00
# Winning round_trips               12.00        12.00
# Losing round_trips                 0.00         0.00
# Even round_trips                   0.00         0.00
# PnL stats                 All trades  Long trades
# Total profit                $3251.12     $3251.12
# Gross profit                $3251.12     $3251.12
# Gross loss                     $0.00        $0.00
# Profit factor                   $nan         $nan
# Avg. trade net profit        $270.93      $270.93
# Avg. winning trade           $270.93      $270.93
# Avg. losing trade               $nan         $nan
# Ratio Avg. Win:Avg. Loss        $nan         $nan
# Largest winning trade       $1451.75     $1451.75
# Largest losing trade          $22.41       $22.41
# Duration stats                  All trades              Long trades
# Avg duration      951 days 12:20:00.333333 951 days 12:20:00.333333
# Median duration         1002 days 23:00:00       1002 days 23:00:00
# Longest duration        1191 days 03:00:01       1191 days 03:00:01
# Shortest duration        271 days 23:00:00        271 days 23:00:00
# Return stats                    All trades  Long trades
# Avg returns all round_trips          2.07%        2.07%
# Avg returns winning                  2.07%        2.07%
# Avg returns losing                    nan%         nan%
# Median returns all round_trips       0.86%        0.86%
# Median returns winning               0.86%        0.86%
# Median returns losing                 nan%         nan%
# Largest winning trade               10.95%       10.95%
# Largest losing trade                 0.20%        0.20%
# Symbol stats                     GLD   SHY    SPY   TLT
# Avg returns all round_trips    2.09% 1.55%  2.67% 1.22%
# Avg returns winning            2.09% 1.55%  2.67% 1.22%
# Avg returns losing              nan%  nan%   nan%  nan%
# Median returns all round_trips 0.40% 1.55%  0.57% 1.23%
# Median returns winning         0.40% 1.55%  0.57% 1.23%
# Median returns losing           nan%  nan%   nan%  nan%
# Largest winning trade          5.64% 1.55% 10.95% 2.23%
# Largest losing trade           0.23% 1.55%  0.24% 0.20%
# Profitability (PnL / PnL total) per name
# symbol
# SPY                                      54.01%
# GLD                                      25.48%
# TLT                                      14.20%
# SHY                                       6.31%
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-13-3343e8c9bcc9> in <module>
#      10 returns, positions, transactions = pf.utils.extract_rets_pos_txn_from_zipline(perf)
#      11
# ---> 12 pf.create_full_tear_sheet(returns, positions=positions, transactions=transactions, bootstrap=None,benchmark_rets=spy_bm_ret, round_trips=True)
#      13 #pf.create_simple_tear_sheet(returns=returns,positions=positions,transactions=transactions)
#
# /home/hca-r2-001/miniconda3/envs/hca/lib/python3.6/site-packages/pyfolio/tears.py in create_full_tear_sheet(returns, positions, transactions, market_data, benchmark_rets, slippage, live_start_date, sector_mappings, bayesian, round_trips, estimate_intraday, hide_positions, cone_std, bootstrap, unadjusted_returns, risk, style_factor_panel, sectors, caps, shares_held, volumes, percentile, set_context)
#     203                     transactions=transactions,
#     204                     sector_mappings=sector_mappings,
# --> 205                     estimate_intraday=False)
#     206
#     207             if market_data is not None:
#
# /home/hca-r2-001/miniconda3/envs/hca/lib/python3.6/site-packages/pyfolio/plotting.py in call_w_context(*args, **kwargs)
#      50         if set_context:
#      51             with plotting_context(), axes_style():
# ---> 52                 return func(*args, **kwargs)
#      53         else:
#      54             return func(*args, **kwargs)
#
# /home/hca-r2-001/miniconda3/envs/hca/lib/python3.6/site-packages/pyfolio/tears.py in create_round_trip_tear_sheet(returns, positions, transactions, sector_mappings, estimate_intraday, return_fig)
#     828     plotting.plot_round_trip_lifetimes(trades, ax=ax_trade_lifetimes)
#     829
# --> 830     plotting.plot_prob_profit_trade(trades, ax=ax_prob_profit_trade)
#     831
#     832     trade_holding_times = [x.days for x in trades['duration']]
#
# /home/hca-r2-001/miniconda3/envs/hca/lib/python3.6/site-packages/pyfolio/plotting.py in plot_prob_profit_trade(round_trips, ax)
#    1871     ax.set_xlabel('Probability of making a profitable decision')
#    1872     ax.set_ylabel('Belief')
# -> 1873     ax.set_xlim(lower_plot, upper_plot)
#    1874     ax.set_ylim((0, y.max() + 1.))
#    1875
#
# /home/hca-r2-001/miniconda3/envs/hca/lib/python3.6/site-packages/matplotlib/axes/_base.py in set_xlim(self, left, right, emit, auto, xmin, xmax)
#    3239
#    3240         self._process_unit_info(xdata=(left, right))
# -> 3241         left = self._validate_converted_limits(left, self.convert_xunits)
#    3242         right = self._validate_converted_limits(right, self.convert_xunits)
#    3243
#
# /home/hca-r2-001/miniconda3/envs/hca/lib/python3.6/site-packages/matplotlib/axes/_base.py in _validate_converted_limits(self, limit, convert)
#    3156             if (isinstance(converted_limit, Real)
#    3157                     and not np.isfinite(converted_limit)):
# -> 3158                 raise ValueError("Axis limits cannot be NaN or Inf")
#    3159             return converted_limit
#    3160
#
# ValueError: Axis limits cannot be NaN or Inf
