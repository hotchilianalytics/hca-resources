# %%
# %%html
# <style>
#   table {margin-left: 0 !important;}
#     td {
#         font-size: 14px
#     }
# </style>
# Out:
# <style>
#   table {margin-left: 0 !important;}
#     td {
#         font-size: 14px
#     }
# </style>

# %% [markdown]
# <img src="http://drive.google.com/uc?export=view&id=1zJjN-vEjutF__7wpEq5Yibxv9BRZeC74"
#      alt="HCA Logo" height="75" width="75"
#      style="float: left; margin-right: 2px;">
#
# |Name  | Value |
# | :- |:-------------: |
# | Notebook: | HotChili Trader Tear Sheet |
# | Version:  | 2.0 |
# | Date:     | 2021-05-03  |
# | Copyright:  | @2019-2021 |
# | Company  | HotChili Analytics, LLC |
# | Author(s)   :  | Alan & Jeff Coppola ||
# |||

# %%
import pandas as pd
import numpy as np
import matplotlib as mp
import matplotlib.pyplot as plt
import pyfolio as pf
# %matplotlib inline

# silence warnings
import warnings
warnings.filterwarnings('ignore')
### %pylab inline
###figsize(12, 12)
# Out:
# WARNING (theano.configdefaults): install mkl with `conda install mkl-service`: No module named 'mkl'
# /home/hca-r2-001/miniconda3/envs/hca/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %%
import os

hca_root_path = os.environ['HCA_ROOT']
print(f"hca_root_path = {hca_root_path}")

# Parameters for location of zipline-broker run
nb_dir = hca_root_path + "/hca-resources/HCA_In_and_Out/" 
#Live ans_pkl = "HCA_In_and_Out.pkl"
#BackTest 
ans_pkl = "HCA_In_and_Out_bt.pkl"
ans_data_file = nb_dir + ans_pkl

# Read in backtest results for analysis
perf=pd.read_pickle(ans_data_file)
# Out:
# hca_root_path = /home/hca-ws2004/hca

# %%
import pandas as pd
returns, positions, transactions= pf.utils.extract_rets_pos_txn_from_zipline(perf)

# %%
#transactions

# %%
import sys

print("Tear Sheet File : {}".format(ans_data_file))
print("-----------------------------------")
print("Python version={}".format(sys.version))
print("Matplotlib version={}".format(mp.__version__))
print("Numpy version={}".format(np.version.version))
# Out:
# Tear Sheet File : /home/hca-ws2004/hca/hca-resources/HCA_In_and_Out/HCA_In_and_Out_bt.pkl
# -----------------------------------
# Python version=3.6.7 |Anaconda, Inc.| (default, Oct 23 2018, 19:16:44)
# [GCC 7.3.0]
# Matplotlib version=3.1.1
# Numpy version=1.14.0

# %%
#pf.plot_drawdown_periods(returns, top=5).set_xlabel('Date')

# %%
#returns.plot()

# %%
#transactions

# %%
#from datetime import datetime
#import pytz
#start = datetime(2017, 2, 11, 0, 0, 0, 0, pytz.utc)
#end = datetime(2019, 3, 14, 0, 0, 0, 0, pytz.utc)
#s=pd.Timestamp(start)

# %%
#pf.create_position_tear_sheet(returns=returns,positions=positions)
#pf.plot_perf_stats(returns= returns, factor_returns=returns)

# %%
sim_start=perf.index[0]
sim_end= perf.index[-1]
print("start={}  end={}".format(sim_start,sim_end))
# Out:
# start=2019-04-01 00:00:00+00:00  end=2021-05-27 00:00:00+00:00

# %%
#%%pixie_debugger

from zipline.data import benchmarks
# Set up benchmark Asset 
spy_bm_ret    = benchmarks.get_benchmark_returns(symbol='SPY', first_date=sim_start, last_date=sim_end)
spy_bm_ret    = spy_bm_ret[sim_start:sim_end]
spy_bm_ret[0] = 0.0 # Normalize benchmark returns to start at 0.0.
perf          = perf[sim_start:sim_end]

returns, positions, transactions = pf.utils.extract_rets_pos_txn_from_zipline(perf)

pf.create_full_tear_sheet(returns, positions=positions, transactions=transactions, bootstrap=None,benchmark_rets=spy_bm_ret, round_trips=True)
#pf.create_simple_tear_sheet(returns=returns,positions=positions,transactions=transactions)
# Out:
# Entire data start date: 2019-04-02
# Entire data end date: 2021-05-27
# Backtest months: 25
#                     Backtest
# Annual return          22.2%
# Cumulative returns     54.2%
# Annual volatility      13.5%
# Sharpe ratio            1.55
# Calmar ratio            1.96
# Stability               0.97
# Max drawdown          -11.4%
# Omega ratio             1.33
# Sortino ratio           2.15
# Skew                   -0.91
# Kurtosis                3.87
# Tail ratio              0.99
# Daily value at risk    -1.6%
# Gross leverage          1.00
# Daily turnover          1.8%
# Alpha                   0.15
# Beta                    0.33
# Worst drawdown periods Net drawdown in %  Peak date Valley date Recovery date  \
# 0                                  11.36 2020-03-06  2020-03-18    2020-04-24
# 1                                  10.30 2020-09-02  2020-09-23    2021-01-20
# 2                                   7.07 2021-02-12  2021-03-08    2021-04-05
# 3                                   5.12 2021-04-16  2021-05-12           NaT
# 4                                   4.89 2019-09-04  2019-10-02    2019-10-24
#
# Worst drawdown periods Duration
# 0                            36
# 1                           101
# 2                            37
# 3                           NaN
# 4                            37
# Stress Events  mean    min   max
# New Normal    0.08% -4.03% 2.73%
# Top 10 long positions of all time    max
# QQQ                               50.58%
# URTH                              50.44%
# SCHD                              36.16%
# TLT                               35.31%
# IEF                               34.30%
# Empty DataFrame
# Columns: [max]
# Index: []
# Top 10 positions of all time    max
# QQQ                          50.58%
# URTH                         50.44%
# SCHD                         36.16%
# TLT                          35.31%
# IEF                          34.30%
# All positions ever held    max
# QQQ                     50.58%
# URTH                    50.44%
# SCHD                    36.16%
# TLT                     35.31%
# IEF                     34.30%
# Summary stats                All trades  Long trades
# Total number of round_trips      332.00       332.00
# Percent profitable                 0.73         0.73
# Winning round_trips              242.00       242.00
# Losing round_trips                90.00        90.00
# Even round_trips                   0.00         0.00
# PnL stats                 All trades  Long trades
# Total profit               $16267.54    $16267.54
# Gross profit               $18609.99    $18609.99
# Gross loss                 $-2342.44    $-2342.44
# Profit factor                  $7.94        $7.94
# Avg. trade net profit         $49.00       $49.00
# Avg. winning trade            $76.90       $76.90
# Avg. losing trade            $-26.03      $-26.03
# Ratio Avg. Win:Avg. Loss       $2.95        $2.95
# Largest winning trade       $2477.99     $2477.99
# Largest losing trade        $-319.14     $-319.14
# Duration stats                 All trades             Long trades
# Avg duration      67 days 17:16:37.596385 67 days 17:16:37.596385
# Median duration          61 days 12:00:00        61 days 12:00:00
# Longest duration        162 days 03:00:01       162 days 03:00:01
# Shortest duration         1 days 00:00:00         1 days 00:00:00
# Return stats                    All trades  Long trades
# Avg returns all round_trips          0.13%        0.13%
# Avg returns winning                  0.20%        0.20%
# Avg returns losing                  -0.07%       -0.07%
# Median returns all round_trips       0.01%        0.01%
# Median returns winning               0.02%        0.02%
# Median returns losing               -0.02%       -0.02%
# Largest winning trade                5.35%        5.35%
# Largest losing trade                -0.92%       -0.92%
# Symbol stats                      IEF    QQQ   SCHD    TLT   URTH
# Avg returns all round_trips     0.10%  0.37%  0.03%  0.14%  0.16%
# Avg returns winning             0.11%  0.41%  0.28%  0.15%  0.18%
# Avg returns losing             -0.01% -0.01% -0.08% -0.00% -0.10%
# Median returns all round_trips  0.02%  0.03% -0.01%  0.06%  0.01%
# Median returns winning          0.02%  0.04%  0.01%  0.06%  0.01%
# Median returns losing          -0.00% -0.01% -0.02% -0.00% -0.00%
# Largest winning trade           1.96%  4.58%  4.27%  3.69%  5.35%
# Largest losing trade           -0.02% -0.01% -0.92% -0.01% -0.47%
# Profitability (PnL / PnL total) per name
# symbol
# QQQ                                      30.02%
# URTH                                     27.71%
# TLT                                      22.66%
# IEF                                      10.84%
# SCHD                                      8.78%
