# %%
# %%html
# <style>
#   table {margin-left: 0 !important;}
# </style>
# Out:
# <style>
#   table {margin-left: 0 !important;}
# </style>

# %% [markdown]
# <img src="http://drive.google.com/uc?export=view&id=1zJjN-vEjutF__7wpEq5Yibxv9BRZeC74"
#      alt="HCA Logo" height="150" width="150"
#      style="float: left; margin-right: 10px;">
#
# |Name  | Value |
# | :- |:-------------: |
# | **Notebook:**  | **HotChili Trader Tear Sheet** |
# | **Version:**  | 1.0.1c |
# | **Date:**  | 2020-08-06  |
# | **Copyright:**  | @2019-2020 |
# | **Company:**  | **HotChili Analytics, LLC** |
# | **Author   :**  | Alan Coppola|(ajjcoppola@hotchilianalytics.com) |
# | **Author   :**  | Jeff Coppola|(jeff@hotchilianalytics.com) |

# %%
import pandas as pd
import numpy as np
import matplotlib as mp
import matplotlib.pyplot as plt
import pyfolio as pf
# %matplotlib inline

# silence warnings
import warnings
warnings.filterwarnings('ignore')
### %pylab inline
###figsize(12, 12)
# Out:
# WARNING (theano.configdefaults): install mkl with `conda install mkl-service`: No module named 'mkl'
# /home/hca-r2-001/miniconda3/envs/hca/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %%
pd.set_option("max_colwidth", 400)
pd.set_option("display.max_rows", 100000)
pd.set_option("display.max_columns", 1000)
pd.set_option('precision', 2)
pd.options.display.float_format = '{:20,.2f}'.format

# %%
import os

hca_root_path = os.environ['HCA_ROOT']
print(f"hca_root_path = {hca_root_path}")

# Parameters for location of zipline-broker run
nb_dir = hca_root_path + "/hca-resources/HCA_Trendfollowing/" 

# Parameters for location of zipline-broker run
ans_pkl = "HCA_Trendfollowing.pkl"
ans_data_file = nb_dir + ans_pkl

# Read in backtest results for analysis
perf=pd.read_pickle(ans_data_file)
# Out:
# hca_root_path = /home/hca-ws2004/hca

# %%
perf.columns
#dir(perf)
# Out:
# Index(['SPY', 'algo_volatility', 'algorithm_period_return', 'alpha',
#        'benchmark_period_return', 'benchmark_volatility', 'beta',
#        'capital_used', 'ending_cash', 'ending_exposure', 'ending_value',
#        'excess_return', 'gross_leverage', 'long_exposure', 'long_value',
#        'longs_count', 'max_drawdown', 'max_leverage', 'net_leverage', 'orders',
#        'period_close', 'period_label', 'period_open', 'pnl', 'portfolio_value',
#        'positions', 'returns', 'sharpe', 'short_exposure', 'short_value',
#        'shorts_count', 'sortino', 'starting_cash', 'starting_exposure',
#        'starting_value', 'trading_days', 'transactions',
#        'treasury_period_return'],
#       dtype='object')

# %%
perf.shape
# Out:
# (694, 38)

# %%
import pandas as pd
returns, positions, transactions= pf.utils.extract_rets_pos_txn_from_zipline(perf)

# %%
#positions

# %%
#transactions

# %%
import sys

print("Tear Sheet File : {}".format(ans_data_file))
print("-----------------------------------")
print("Python version={}".format(sys.version))
print("Matplotlib version={}".format(mp.__version__))
print("Numpy version={}".format(np.version.version))
# Out:
# Tear Sheet File : /home/hca-ws2004/hca/hca-resources/HCA_Trendfollowing/HCA_Trendfollowing.pkl
# -----------------------------------
# Python version=3.6.7 |Anaconda, Inc.| (default, Oct 23 2018, 19:16:44)
# [GCC 7.3.0]
# Matplotlib version=3.1.1
# Numpy version=1.14.0

# %%
#pf.plot_drawdown_periods(returns, top=5).set_xlabel('Date')

# %%
#returns.plot()

# %%
#transactions

# %%
#from datetime import datetime
#import pytz
#start = datetime(2017, 2, 11, 0, 0, 0, 0, pytz.utc)
#end = datetime(2019, 3, 14, 0, 0, 0, 0, pytz.utc)
#s=pd.Timestamp(start)

# %%
#pf.create_position_tear_sheet(returns=returns,positions=positions)
#pf.plot_perf_stats(returns= returns, factor_returns=returns)

# %%
sim_start=perf.index[0]
sim_end= perf.index[-1]
print("start={}  end={}".format(sim_start,sim_end))
# Out:
# start=2018-01-02 00:00:00+00:00  end=2020-10-02 00:00:00+00:00

# %%
#%%pixie_debugger

from zipline.data import benchmarks
# Set up benchmark Asset 
spy_bm_ret    = benchmarks.get_benchmark_returns(symbol='SPY', first_date=sim_start, last_date=sim_end)
spy_bm_ret    = spy_bm_ret[sim_start:sim_end]
spy_bm_ret[0] = 0.0 # Normalize benchmark returns to start at 0.0.
perf          = perf[sim_start:sim_end]

returns, positions, transactions = pf.utils.extract_rets_pos_txn_from_zipline(perf)

pf.create_full_tear_sheet(returns, positions=positions, transactions=transactions, bootstrap=None,benchmark_rets=spy_bm_ret, round_trips=True)
#pf.create_simple_tear_sheet(returns=returns,positions=positions,transactions=transactions)
# Out:
# Entire data start date: 2018-01-03
# Entire data end date: 2020-10-02
# Backtest months: 33
#                     Backtest
# Annual return           5.8%
# Cumulative returns     16.8%
# Annual volatility      11.9%
# Sharpe ratio            0.53
# Calmar ratio            0.55
# Stability               0.66
# Max drawdown          -10.6%
# Omega ratio             1.12
# Sortino ratio           0.68
# Skew                   -1.57
# Kurtosis                8.80
# Tail ratio              1.03
# Daily value at risk    -1.5%
# Gross leverage          0.95
# Daily turnover          5.7%
# Alpha                   0.04
# Beta                    0.27
# Worst drawdown periods Net drawdown in %  Peak date Valley date Recovery date  \
# 0                                  10.60 2020-02-19  2020-02-27    2020-08-10
# 1                                   9.72 2018-01-26  2018-02-08    2019-04-23
# 2                                   7.89 2020-09-02  2020-09-23           NaT
# 3                                   6.91 2019-07-26  2019-08-23    2019-11-15
# 4                                   6.52 2019-05-03  2019-06-04    2019-07-11
#
# Worst drawdown periods Duration
# 0                           124
# 1                           323
# 2                           NaN
# 3                            81
# 4                            50
# Stress Events  mean    min   max
# New Normal    0.03% -5.22% 3.67%
# Top 10 long positions of all time     max
# SHY                               102.65%
# SPY                               101.66%
# Empty DataFrame
# Columns: [max]
# Index: []
# Top 10 positions of all time     max
# SHY                          102.65%
# SPY                          101.66%
# All positions ever held     max
# SHY                     102.65%
# SPY                     101.66%
# Summary stats                All trades  Long trades
# Total number of round_trips       63.00        63.00
# Percent profitable                 0.65         0.65
# Winning round_trips               41.00        41.00
# Losing round_trips                22.00        22.00
# Even round_trips                   0.00         0.00
# PnL stats                 All trades  Long trades
# Total profit                $1683.92     $1683.92
# Gross profit                $2828.86     $2828.86
# Gross loss                 $-1144.94    $-1144.94
# Profit factor                  $2.47        $2.47
# Avg. trade net profit         $26.73       $26.73
# Avg. winning trade            $69.00       $69.00
# Avg. losing trade            $-52.04      $-52.04
# Ratio Avg. Win:Avg. Loss       $1.33        $1.33
# Largest winning trade        $784.62      $784.62
# Largest losing trade        $-399.91     $-399.91
# Duration stats                 All trades             Long trades
# Avg duration      34 days 21:23:48.587301 34 days 21:23:48.587301
# Median duration          13 days 00:00:00        13 days 00:00:00
# Longest duration        126 days 01:00:00       126 days 01:00:00
# Shortest duration         1 days 00:00:00         1 days 00:00:00
# Return stats                    All trades  Long trades
# Avg returns all round_trips          0.24%        0.24%
# Avg returns winning                  0.65%        0.65%
# Avg returns losing                  -0.51%       -0.51%
# Median returns all round_trips       0.08%        0.08%
# Median returns winning               0.18%        0.18%
# Median returns losing               -0.15%       -0.15%
# Largest winning trade                6.66%        6.66%
# Largest losing trade                -4.06%       -4.06%
# Symbol stats                      SHY    SPY
# Avg returns all round_trips     0.04%  0.34%
# Avg returns winning             0.41%  0.69%
# Avg returns losing             -0.11% -1.38%
# Median returns all round_trips -0.08%  0.13%
# Median returns winning          0.32%  0.18%
# Median returns losing          -0.10% -1.27%
# Largest winning trade           1.18%  6.66%
# Largest losing trade           -0.20% -4.06%
# Profitability (PnL / PnL total) per name
# symbol
# SPY                                      95.02%
# SHY                                       4.98%
