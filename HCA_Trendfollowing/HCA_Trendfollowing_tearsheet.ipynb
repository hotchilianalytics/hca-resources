# %%
# %%html
# <style>
#   table {margin-left: 0 !important;}
# </style>
# Out:
# <style>
#   table {margin-left: 0 !important;}
# </style>

# %% [markdown]
# <img src="http://drive.google.com/uc?export=view&id=1zJjN-vEjutF__7wpEq5Yibxv9BRZeC74"
#      alt="HCA Logo" height="150" width="150"
#      style="float: left; margin-right: 10px;">
#
# |Name  | Value |
# | :- |:-------------: |
# | **Notebook:**  | **HotChili Trader Tear Sheet** |
# | **Version:**  | 1.0.1c |
# | **Date:**  | 2020-08-06  |
# | **Copyright:**  | @2019-2020 |
# | **Company:**  | **HotChili Analytics, LLC** |
# | **Author   :**  | Alan Coppola|(ajjcoppola@hotchilianalytics.com) |
# | **Author   :**  | Jeff Coppola|(jeff@hotchilianalytics.com) |

# %%
import pandas as pd
import numpy as np
import matplotlib as mp
import matplotlib.pyplot as plt
import pyfolio as pf
# %matplotlib inline

# silence warnings
import warnings
warnings.filterwarnings('ignore')
### %pylab inline
###figsize(12, 12)
# Out:
# WARNING (theano.configdefaults): install mkl with `conda install mkl-service`: No module named 'mkl'
# /home/hca-dev/miniconda3/envs/hca/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %%
pd.set_option("max_colwidth", 400)
pd.set_option("display.max_rows", 100000)
pd.set_option("display.max_columns", 1000)
pd.set_option('precision', 2)
pd.options.display.float_format = '{:20,.2f}'.format

# %%
# Parameters for location of zipline-broker run
nb_dir = "/home/hca-dev/hca/strats/logs/"
ans_pkl = "zlb-segmsec-bt.pkl"
ans_data_file = nb_dir + ans_pkl

# Read in backtest results for analysis
perf=pd.read_pickle(ans_data_file)

# %%
perf.columns
#dir(perf)
# Out:
# Index(['CAGR', 'Lv', 'PnL', 'Shorts', 'algo_volatility',
#        'algorithm_period_return', 'alpha', 'benchmark_period_return',
#        'benchmark_volatility', 'beta', 'capital_used', 'ending_cash',
#        'ending_exposure', 'ending_value', 'excess_return', 'gross_leverage',
#        'long_exposure', 'long_value', 'longs_count', 'max_drawdown',
#        'max_leverage', 'net_leverage', 'orders', 'period_close',
#        'period_label', 'period_open', 'pnl', 'portfolio_value', 'positions',
#        'returns', 'sharpe', 'short_exposure', 'short_value', 'shorts_count',
#        'sortino', 'starting_cash', 'starting_exposure', 'starting_value',
#        'trading_days', 'transactions', 'treasury_period_return'],
#       dtype='object')

# %%
perf.shape
# Out:
# (520, 41)

# %%
import pandas as pd
returns, positions, transactions= pf.utils.extract_rets_pos_txn_from_zipline(perf)

# %%
#positions

# %%
#transactions

# %%
import sys

print("Tear Sheet File : {}".format(ans_data_file))
print("-----------------------------------")
print("Python version={}".format(sys.version))
print("Matplotlib version={}".format(mp.__version__))
print("Numpy version={}".format(np.version.version))
# Out:
# Tear Sheet File : /home/hca-dev/hca/strats/logs/zlb-segmsec-bt.pkl
# -----------------------------------
# Python version=3.6.7 |Anaconda, Inc.| (default, Oct 23 2018, 19:16:44)
# [GCC 7.3.0]
# Matplotlib version=3.1.1
# Numpy version=1.14.1

# %%
#pf.plot_drawdown_periods(returns, top=5).set_xlabel('Date')

# %%
#returns.plot()

# %%
#transactions

# %%
#from datetime import datetime
#import pytz
#start = datetime(2017, 2, 11, 0, 0, 0, 0, pytz.utc)
#end = datetime(2019, 3, 14, 0, 0, 0, 0, pytz.utc)
#s=pd.Timestamp(start)

# %%
#pf.create_position_tear_sheet(returns=returns,positions=positions)
#pf.plot_perf_stats(returns= returns, factor_returns=returns)

# %%
sim_start=perf.index[0]
sim_end= perf.index[-1]
print("start={}  end={}".format(sim_start,sim_end))
# Out:
# start=2018-12-03 00:00:00+00:00  end=2020-12-24 00:00:00+00:00

# %%
#%%pixie_debugger

from zipline.data import benchmarks
# Set up benchmark Asset 
spy_bm_ret    = benchmarks.get_benchmark_returns(symbol='SPY', first_date=sim_start, last_date=sim_end)
spy_bm_ret    = spy_bm_ret[sim_start:sim_end]
spy_bm_ret[0] = 0.0 # Normalize benchmark returns to start at 0.0.
perf          = perf[sim_start:sim_end]

returns, positions, transactions = pf.utils.extract_rets_pos_txn_from_zipline(perf)

pf.create_full_tear_sheet(returns, positions=positions, transactions=transactions, bootstrap=None,benchmark_rets=spy_bm_ret, round_trips=True)
#pf.create_simple_tear_sheet(returns=returns,positions=positions,transactions=transactions)
# Out:
# Entire data start date: 2018-12-04
# Entire data end date: 2020-12-24
# Backtest months: 24
#                     Backtest
# Annual return          46.2%
# Cumulative returns    118.6%
# Annual volatility      22.3%
# Sharpe ratio            1.82
# Calmar ratio            2.49
# Stability               0.87
# Max drawdown          -18.5%
# Omega ratio             1.39
# Sortino ratio           2.71
# Skew                   -0.26
# Kurtosis                4.76
# Tail ratio              1.11
# Daily value at risk    -2.6%
# Gross leverage          1.19
# Daily turnover          4.6%
# Alpha                   0.36
# Beta                    0.57
# Worst drawdown periods Net drawdown in %  Peak date Valley date Recovery date  \
# 0                                  18.53 2020-02-20  2020-03-18    2020-04-17
# 1                                  16.44 2019-06-20  2019-09-27    2020-01-07
# 2                                   7.74 2020-09-01  2020-09-17    2020-10-13
# 3                                   6.19 2019-05-03  2019-05-13    2019-05-28
# 4                                   5.85 2020-10-27  2020-11-02    2020-11-27
#
# Worst drawdown periods Duration
# 0                            42
# 1                           144
# 2                            31
# 3                            18
# 4                            24
# Stress Events  mean    min   max
# New Normal    0.16% -7.25% 6.76%
# Top 10 long positions of all time    max
# SHOP                              23.09%
# EVBG                              12.48%
# APPF                              11.93%
# SPLK                              10.06%
# PS                                 8.50%
# CHGG                               8.44%
# NOW                                8.08%
# TEAM                               7.92%
# TLND                               7.67%
# TWOU                               7.62%
# Top 10 short positions of all time    max
# DOCU                               -9.00%
# FIVN                               -4.78%
# PD                                 -4.47%
# SMAR                               -4.43%
# PLAN                               -4.41%
# PS                                 -4.21%
# VEEV                               -3.90%
# MIME                               -3.57%
# BOX                                -3.57%
# NOW                                -3.55%
# Top 10 positions of all time    max
# SHOP                         23.09%
# EVBG                         12.48%
# APPF                         11.93%
# SPLK                         10.06%
# DOCU                          9.00%
# PS                            8.50%
# CHGG                          8.44%
# NOW                           8.08%
# TEAM                          7.92%
# TLND                          7.67%
# All positions ever held    max
# SHOP                    23.09%
# EVBG                    12.48%
# APPF                    11.93%
# SPLK                    10.06%
# DOCU                     9.00%
# PS                       8.50%
# CHGG                     8.44%
# NOW                      8.08%
# TEAM                     7.92%
# TLND                     7.67%
# TWOU                     7.62%
# ADBE                     7.49%
# ADSK                     7.47%
# PLAN                     7.45%
# WDAY                     7.45%
# TWLO                     7.43%
# HUBS                     7.37%
# MIME                     7.36%
# CRM                      7.35%
# AVLR                     7.34%
# WORK                     7.30%
# NEWR                     7.28%
# ZM                       7.27%
# CSOD                     7.26%
# MOBL                     7.23%
# BL                       7.23%
# FIVN                     7.17%
# SPSC                     7.16%
# VEEV                     7.15%
# BOX                      7.13%
# RP                       7.12%
# QTWO                     7.04%
# PD                       6.97%
# SMAR                     4.43%
# RNG                      3.65%
# OKTA                     3.11%
# ZEN                      1.83%
# Summary stats                All trades  Short trades  Long trades
# Total number of round_trips     1262.00        614.00       648.00
# Percent profitable                 0.56          0.47         0.65
# Winning round_trips              708.00        289.00       419.00
# Losing round_trips               553.00        325.00       228.00
# Even round_trips                   1.00          0.00         1.00
# PnL stats                 All trades  Short trades  Long trades
# Total profit               $36273.80    $-14061.15    $50334.94
# Gross profit               $67372.99      $8093.85    $59279.15
# Gross loss                $-31099.20    $-22154.99    $-8944.20
# Profit factor                  $2.17         $0.37        $6.63
# Avg. trade net profit         $28.74       $-22.90       $77.68
# Avg. winning trade            $95.16        $28.01      $141.48
# Avg. losing trade            $-56.24       $-68.17      $-39.23
# Ratio Avg. Win:Avg. Loss       $1.69         $0.41        $3.61
# Largest winning trade      $13237.32       $464.70    $13237.32
# Largest losing trade       $-4147.96     $-4147.96     $-801.92
# Duration stats                 All trades            Short trades  \
# Avg duration      27 days 16:12:38.824088 25 days 04:24:43.418566
# Median duration          10 days 00:00:00        10 days 00:00:00
# Longest duration        736 days 03:00:01       736 days 03:00:01
# Shortest duration         1 days 00:00:00         1 days 00:00:00
#
# Duration stats                Long trades
# Avg duration      30 days 00:52:18.915123
# Median duration          11 days 00:00:00
# Longest duration        733 days 03:00:01
# Shortest duration         1 days 00:00:00
# Return stats                    All trades  Short trades  Long trades
# Avg returns all round_trips          0.05%        -0.03%        0.14%
# Avg returns winning                  0.18%         0.07%        0.26%
# Avg returns losing                  -0.11%        -0.12%       -0.09%
# Median returns all round_trips       0.00%        -0.00%        0.02%
# Median returns winning               0.05%         0.03%        0.06%
# Median returns losing               -0.03%        -0.03%       -0.04%
# Largest winning trade               20.19%         0.75%       20.19%
# Largest losing trade                -6.33%        -6.33%       -1.39%
# Symbol stats                     ADBE   ADSK   APPF   AVLR     BL    BOX  \
# Avg returns all round_trips     0.04%  0.01%  0.68%  0.01%  0.31%  0.02%
# Avg returns winning             0.11%  0.10%  0.83%  0.11%  0.45%  0.09%
# Avg returns losing             -0.05% -0.09% -0.02% -0.11% -0.06% -0.06%
# Median returns all round_trips  0.02%  0.00%  0.02%  0.00%  0.03%  0.00%
# Median returns winning          0.08%  0.03%  0.02%  0.03%  0.05%  0.05%
# Median returns losing          -0.04% -0.05% -0.02% -0.03% -0.05% -0.03%
# Largest winning trade           0.42%  0.96%  7.01%  0.92%  2.91%  0.69%
# Largest losing trade           -0.28% -0.80% -0.04% -1.71% -0.12% -0.32%
#
# Symbol stats                     CHGG    CRM   CSOD   DOCU   EVBG   FIVN  \
# Avg returns all round_trips     0.06% -0.02%  0.03% -0.15%  1.55% -0.01%
# Avg returns winning             0.22%  0.05%  0.08%  0.11%  2.08%  0.07%
# Avg returns losing             -0.07% -0.06% -0.05% -0.48% -0.04% -0.14%
# Median returns all round_trips -0.01% -0.01%  0.01%  0.00%  0.03%  0.01%
# Median returns winning          0.04%  0.03%  0.05%  0.07%  0.06%  0.03%
# Median returns losing          -0.02% -0.04% -0.04% -0.02% -0.04% -0.02%
# Largest winning trade           2.16%  0.48%  0.44%  0.42%  6.17%  0.55%
# Largest losing trade           -0.53% -0.25% -0.19% -6.33% -0.04% -2.66%
#
# Symbol stats                     HUBS   MIME   MOBL   NEWR    NOW   OKTA  \
# Avg returns all round_trips     0.09%  0.02% -0.01%  0.02%  0.04% -0.41%
# Avg returns winning             0.17%  0.11%  0.10%  0.09%  0.21%  0.20%
# Avg returns losing             -0.03% -0.06% -0.08% -0.06% -0.36% -1.62%
# Median returns all round_trips  0.01% -0.00% -0.02%  0.00%  0.05%  0.00%
# Median returns winning          0.04%  0.04%  0.07%  0.05%  0.10%  0.20%
# Median returns losing          -0.02% -0.01% -0.02% -0.04% -0.06% -1.62%
# Largest winning trade           2.16%  0.37%  0.22%  0.64%  1.17%  0.40%
# Largest losing trade           -0.13% -0.46% -0.50% -0.23% -1.89% -1.62%
#
# Symbol stats                       PD   PLAN     PS   QTWO   RNG     RP  \
# Avg returns all round_trips    -0.09%  0.01% -0.10% -0.04% 1.15%  0.06%
# Avg returns winning             0.19%  0.14%  0.08%  0.06% 1.15%  0.13%
# Avg returns losing             -0.53% -0.19% -0.28% -0.15%  nan% -0.05%
# Median returns all round_trips  0.03%  0.03% -0.01% -0.00% 0.44%  0.01%
# Median returns winning          0.09%  0.10%  0.05%  0.04% 0.44%  0.03%
# Median returns losing          -0.14% -0.07% -0.14% -0.06%  nan% -0.03%
# Largest winning trade           0.75%  0.59%  0.22%  0.33% 2.99%  1.95%
# Largest losing trade           -1.79% -2.08% -1.11% -0.96% 0.01% -0.33%
#
# Symbol stats                     SHOP   SMAR   SPLK   SPSC   TEAM   TLND  \
# Avg returns all round_trips     6.78% -0.43%  0.07%  0.09%  0.06%  0.02%
# Avg returns winning             6.78%   nan%  0.19%  0.17%  0.13%  0.18%
# Avg returns losing               nan% -0.43% -0.06% -0.07% -0.04% -0.06%
# Median returns all round_trips  0.11% -0.12%  0.00%  0.00%  0.01% -0.01%
# Median returns winning          0.11%   nan%  0.08%  0.02%  0.04%  0.05%
# Median returns losing            nan% -0.12% -0.03% -0.04% -0.03% -0.02%
# Largest winning trade          20.19% -0.05%  3.05%  3.51%  0.68%  0.72%
# Largest losing trade            0.04% -1.40% -0.30% -0.40% -0.15% -0.33%
#
# Symbol stats                     TWLO   TWOU   VEEV   WDAY   WORK   ZEN     ZM
# Avg returns all round_trips     0.03%  0.03% -0.06%  0.06%  0.01% 0.41%  0.30%
# Avg returns winning             0.11%  0.13%  0.07%  0.19%  0.11% 0.41%  0.45%
# Avg returns losing             -0.07% -0.19% -0.13% -0.12% -0.09%  nan% -0.04%
# Median returns all round_trips  0.00%  0.04% -0.02%  0.01% -0.00% 0.41%  0.03%
# Median returns winning          0.03%  0.10%  0.04%  0.05%  0.05% 0.41%  0.10%
# Median returns losing          -0.02% -0.01% -0.09% -0.04% -0.01%  nan% -0.03%
# Largest winning trade           0.96%  0.38%  0.18%  1.44%  0.53% 0.56%  3.71%
# Largest losing trade           -0.78% -1.39% -0.41% -1.12% -0.48% 0.26% -0.09%
# Profitability (PnL / PnL total) per name
# symbol
# SHOP                                      36.62%
# APPF                                      13.05%
# EVBG                                      11.17%
# SPSC                                       8.08%
# ZM                                         7.90%
# SPLK                                       7.37%
# HUBS                                       6.42%
# BL                                         5.88%
# RNG                                        5.79%
# RP                                         4.97%
# CHGG                                       4.28%
# WDAY                                       3.92%
# TEAM                                       3.82%
# CSOD                                       2.26%
# NEWR                                       1.90%
# ADBE                                       1.56%
# TWOU                                       1.42%
# TWLO                                       1.38%
# ZEN                                        1.22%
# BOX                                        0.93%
# MIME                                       0.78%
# ADSK                                       0.24%
# TLND                                      -0.16%
# WORK                                      -0.24%
# MOBL                                      -0.35%
# AVLR                                      -0.55%
# NOW                                       -0.87%
# PLAN                                      -1.05%
# CRM                                       -1.10%
# VEEV                                      -1.64%
# PD                                        -1.82%
# QTWO                                      -2.10%
# PS                                        -2.55%
# OKTA                                      -2.59%
# FIVN                                      -2.74%
# SMAR                                      -2.83%
# DOCU                                     -10.36%
